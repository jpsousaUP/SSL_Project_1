# %%
import cv2
import numpy as np  
import matplotlib.pyplot as plt

from mcap_ros2.decoder import DecoderFactory
from mcap.reader import make_reader
import os
import csv

# %%
import dotenv
#
project_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
print(project_dir)
dotenv_path = os.path.join(project_dir, '.env')
dotenv.load_dotenv(dotenv_path)

print(os.getenv('PROJECT_DIR'))
# Out:
# /home/vm/Joao
# None

# %%
# define bag name =
bag_name = os.getenv('BAG_NAME')
print(bag_name)
# bag path
#bag_path = os.path.join(project_dir, 'data', 'raw', bag_name, bag_name + '_0.mcap')
bag_path = os.path.join(project_dir, 'data', 'raw', bag_name)
# list all mcap files
mcap_files = [os.path.join(bag_path, f) for f in os.listdir(bag_path) if f.endswith('.mcap')]
mcap_files.sort()
print(mcap_files)
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 print(bag_name)
#       4 # bag path
#       5 #bag_path = os.path.join(project_dir, 'data', 'raw', bag_name, bag_name + '_0.mcap')
# ----> 6 bag_path = os.path.join(project_dir, 'data', 'raw', bag_name)
#       7 # list all mcap files
#       8 mcap_files = [os.path.join(bag_path, f) for f in os.listdir(bag_path) if f.endswith('.mcap')]
#
# File /usr/lib/python3.10/posixpath.py:90, in join(a, *p)
#      88             path += sep + b
#      89 except (TypeError, AttributeError, BytesWarning):
# ---> 90     genericpath._check_arg_types('join', a, *p)
#      91     raise
#      92 return path
#
# File /usr/lib/python3.10/genericpath.py:152, in _check_arg_types(funcname, *args)
#     150         hasbytes = True
#     151     else:
# --> 152         raise TypeError(f'{funcname}() argument must be str, bytes, or '
#     153                         f'os.PathLike object, not {s.__class__.__name__!r}') from None
#     154 if hasstr and hasbytes:
#     155     raise TypeError("Can't mix strings and bytes in path components") from None
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'NoneType'

# %%
itermin_data_path = os.path.join(project_dir, 'data', 'interim')

# %%
# in intermin folder, create a folders for xiris, manta and plc if this folders do not exist
if not os.path.exists(os.path.join(itermin_data_path, 'xiris')):
    os.makedirs(os.path.join(itermin_data_path, 'xiris'))
if not os.path.exists(os.path.join(itermin_data_path, 'manta')):
    os.makedirs(os.path.join(itermin_data_path, 'manta'))
if not os.path.exists(os.path.join(itermin_data_path, 'plc')):
    os.makedirs(os.path.join(itermin_data_path, 'plc'))

# %%
# function to read the ros2 msg and save the image
def save_compressed_image(msg_data, folder, image_name):
    # Convert the byte array to a numpy array
    nparr = np.frombuffer(msg_data, np.uint8)
    # Decode the image
    image = cv2.imdecode(nparr, cv2.IMREAD_UNCHANGED)
    # Save the image
    cv2.imwrite(os.path.join(folder, image_name), image)

# %%
def plc_msg_to_csv(plc_msg, time_stamp, csv_path):
    # create a big dictionary with the plc_dict and robot_dict and the time_stamp
    data = {
        'time_stamp': time_stamp,
        'program_running': plc_msg.plc.program_running,
        'laser_on': plc_msg.plc.laser_on,
        'laser_power_out': plc_msg.plc.laser_power_out,
        'laser_power_in': plc_msg.plc.laser_power_in,
        'laser_freq_out': plc_msg.plc.laser_freq_out,
        'laser_program': plc_msg.plc.laser_program,
        'act_nozzlegas': plc_msg.plc.act_nozzlegas,
        'pf1_start_process': plc_msg.plc.pf1_start_process,
        'pf1_act_speed': plc_msg.plc.pf1_act_speed,
        'pf1_act_carr_gas': plc_msg.plc.pf1_act_carr_gas,
        'pf1_act_feed': plc_msg.plc.pf1_act_feed,
        'pf1_act_flowwatch': plc_msg.plc.pf1_act_flowwatch,
        'pf2_start_process': plc_msg.plc.pf2_start_process,
        'pf2_act_speed': plc_msg.plc.pf2_act_speed,
        'pf2_act_carr_gas': plc_msg.plc.pf2_act_carr_gas,
        'pf2_act_feed': plc_msg.plc.pf2_act_feed,
        'pf2_act_flowwatch': plc_msg.plc.pf2_act_flowwatch,
        'base_number': plc_msg.robot.base_number,
        'pos_x': plc_msg.robot.pos_x,
        'vel_x': plc_msg.robot.vel_x,
        'acc_x': plc_msg.robot.acc_x,
        'pos_y': plc_msg.robot.pos_y,
        'vel_y': plc_msg.robot.vel_y,
        'acc_y': plc_msg.robot.acc_y,
        'pos_z': plc_msg.robot.pos_z,
        'vel_z': plc_msg.robot.vel_z,
        'acc_z': plc_msg.robot.acc_z,
        'pos_a': plc_msg.robot.pos_a,
        'vel_a': plc_msg.robot.vel_a,
        'acc_a': plc_msg.robot.acc_a,
        'pos_b': plc_msg.robot.pos_b,
        'vel_b': plc_msg.robot.vel_b,
        'acc_b': plc_msg.robot.acc_b,
        'pos_c': plc_msg.robot.pos_c,
        'vel_c': plc_msg.robot.vel_c,
        'acc_c': plc_msg.robot.acc_c,
        'robot_is': plc_msg.robot.robot_is,
        'robot_it': plc_msg.robot.robot_it,
    }

    # append the data to the csv file
    with open(csv_path, 'a+', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=data.keys())
        writer.writerow(data)
    return data

# %%
time_stamp = 0
xiris_stamp = 0
manta_stamp = 0
first_time = 0
id = 0

for mcap_file in mcap_files:
    with open(mcap_file, "rb") as f:
        reader = make_reader(f, decoder_factories=[DecoderFactory()])
        for schema, channel, message, ros_msg in reader.iter_decoded_messages():
            print(f"{channel.topic} {schema.name} [{message.log_time}")
            if channel.topic == "/xiris/compressed":
                # save the ros2 image into xiris folder with the timestamp as name
                xiris_folder = os.path.join(itermin_data_path, 'xiris', )
                # save the ros2 image
                save_compressed_image(ros_msg.data, xiris_folder, str(message.log_time) + ".png")
                # save the timestamp
                xiris_stamp = message.log_time
            elif channel.topic == "/manta/compressed":
                # save the ros2 image into manta folder with the timestamp as name
                manta_folder = os.path.join(itermin_data_path, 'manta')
                # save the ros2 image
                save_compressed_image(ros_msg.data, manta_folder, str(message.log_time) + ".png")
                # save the timestamp
                manta_stamp = message.log_time
            elif channel.topic == "/ads":
                # save the plc data to a csv file
                plc_csv_path = os.path.join(itermin_data_path, 'plc', 'plc.csv')
                plc_msg_to_csv(ros_msg, message.log_time, plc_csv_path)     
            
            id += 1 
            data = {
                'id': id,
                'time_stamp': message.log_time,
                'xiris_stamp': xiris_stamp,
                'manta_stamp': manta_stamp,
            }
            if manta_stamp > 0 and xiris_stamp > 0 :
                # append the data to the csv file
                timestamps_path = os.path.join(itermin_data_path, 'timestamps.csv')
                # if the file does not exist, create it and add the header
                if not os.path.exists(timestamps_path):
                    with open(timestamps_path, 'w', newline='') as f:
                        writer = csv.DictWriter(f, fieldnames=data.keys())
                        writer.writeheader()
                with open(timestamps_path, 'a+', newline='') as f:
                    writer = csv.DictWriter(f, fieldnames=data.keys())
                    writer.writerow(data)
# Out:
# /ads lmd_interfaces/msg/PlcData [1688480735004978800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735011564700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735021109700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735025493100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735040535600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735043107500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735056585100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735065520900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735072088100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735087793500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735087874100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735102785600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735109862400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735117525600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735132234900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735133638500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735148286900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735154377500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735164336900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735176545400
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480735178667100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735180192200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735194429500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735198978800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735209706900
# /ads lmd_interfaces/msg/PlcData [1688480735217366300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735221203300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735225039000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735241392100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735243440500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735256651900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735265566400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735272897100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735287702700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735288462000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735304125200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735309985600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735319593100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735332190400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735334920100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735351680200
# /ads lmd_interfaces/msg/PlcData [1688480735353850300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735354546000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735367130600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735376989600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735382213800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735397258600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735399105800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735413577100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735421186900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735430724000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735443339900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735446939200
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480735448022400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735463243500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735465643500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735478491200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735488050700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735493944200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735509749500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735510275900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735525492200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735532378500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735542075300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735554581700
# /ads lmd_interfaces/msg/PlcData [1688480735557121700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735557709000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735574140000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735576955900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735589611000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735599116400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735604496100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735619707700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735621230200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735637043200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735643515900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735653271300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735665554000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735668802900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735685278900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735687895600
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480735696145600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735701471000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735710350100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735716960500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735732307200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735732662100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735748503600
# /ads lmd_interfaces/msg/PlcData [1688480735748794100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735754601400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735765176500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735776942300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735780890300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735797271600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735798982900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735812816500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735821277500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735828408100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735843461500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735844044500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735859902700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735866193700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735876195800
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735888097700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735892572300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735907763300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735910443400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735923805900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735932753100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735940147200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735954697100
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480735956685000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735957390600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735973317000
# /ads lmd_interfaces/msg/PlcData [1688480735975277200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735977968700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480735989319800
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480735999073600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736004567600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736019775000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736021634700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736035256000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736043538700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736051676000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736065850700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736067819900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736083133400
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736087932300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736099358300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736110213600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736114622300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736129889900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736133731100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736145199400
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736155393800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736161540900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736177042400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736177696800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736193088900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736199080100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736208322100
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480736216549500
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736221365700
# /ads lmd_interfaces/msg/PlcData [1688480736222385000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736224397100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736239519600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736243955700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736254958000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736265934500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736270010600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736285773700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736289525100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736301254200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736310222200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736317455300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736332653000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736332742000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736349426000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736354829300
# /ads lmd_interfaces/msg/PlcData [1688480736355946000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736365745900
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736376928100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736382029000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736399146300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736399389100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736414735300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736421803300
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736429952700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736443787700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736446645600
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736462853400
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736466153900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736479256400
# /ipcamera/stream2 sensor_msgs/msg/Image [1688480736486994100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736488790700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736495872800
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736510607100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736511237700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736526966600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736532975100
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736543586400
# /ads lmd_interfaces/msg/PlcData [1688480736553421400
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736554761400
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736559121500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736574699600
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736577088700
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736590915300
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736599291200
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736607128100
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736621674900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736624311500
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736640320700
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736643762800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736657095200
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736665864800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736673675000
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736688200000
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736690296800
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480736706868800
# /manta/compressed sensor_msgs/msg/CompressedImage [1688480736710212900
# /xiris/compressed sensor_msgs/msg/CompressedImage [1688480