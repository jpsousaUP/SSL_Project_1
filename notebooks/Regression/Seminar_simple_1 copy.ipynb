# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation
import numpy as np

# verify if GPU is available
print(tf.test.is_gpu_available())

# set memory growth to true
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Setting memory growth to True for GPU: ", physical_devices[0])
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# dont display much info of tensorflow
tf.get_logger().setLevel('ERROR')
# Out:
# True
# Setting memory growth to True for GPU:  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 2024-01-18 15:42:33.414534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-18 15:42:33.415627: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-18 15:42:33.416006: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-18 15:42:33.417035: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-

# %%
# Load data
manta_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_manta.npy"
xiris_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_xiris.npy"
y_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_y.npy"
feats_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_feats.npy"

# load numpy arrays and display shapes
manta = np.load(manta_path)
xiris = np.load(xiris_path)
y = np.load(y_path) # only laser power and velocity
print("manta shape: ", manta.shape)
print("xiris shape: ", xiris.shape)
print("y shape: ", y.shape) # laser power and velocity

feats = np.load(feats_path)
print("feats shape: ", feats.shape) # feats shape:  (100, 2, 2, 2, 2, 2, 2, 2, 2, 2)
# Out:
# L355
# 2024-01-18 15:42:33.417445: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-18 15:42:33.417859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 46872 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:07:00.0, compute capability: 8.6
# manta shape:  (9587, 320, 320)
# xiris shape:  (9587, 320, 320)
# y shape:  (9587, 2)
# feats shape:  (9587, 8)

# %%
# dimensions of MP are the index 1 and 2 of column in feat
dim_lh = feats[:, 1:3]

max_lh = dim_lh.max(axis=0)
# normalize dim_lh based on max value of each column
dim_lh = dim_lh / max_lh

dim_lh
# Out:
# array([[0.11637931, 0.13836478],
#        [0.11206897, 0.1572327 ],
#        [0.14224138, 0.13836478],
#        ...,
#        [0.87068966, 0.47798742],
#        [0.87068966, 0.47798742],
#        [0.85344828, 0.48427673]])

# %%
# concatenate manta and xiris images with label y_encoded as rows
# concatenate the two inputs (manta and xiris) along rows
# expand the dimension of x to 4D
manta = np.expand_dims(manta, axis=3)
xiris = np.expand_dims(xiris, axis=3)
x = np.concatenate((manta, xiris), axis=3)
y = dim_lh
print("x shape: ", x.shape)
print("y shape: ", y.shape)
# Out:
# x shape:  (9587, 320, 320, 2)
# y shape:  (9587, 2)

# %%
# split data into train and test (manta as input and y as output) with shuffle as true
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=42)
print("x_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("x_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (7669, 320, 320, 2)
# y_train shape:  (7669, 2)
# x_test shape:  (1918, 320, 320, 2)
# y_test shape:  (1918, 2)

# %%
del manta, xiris, y, dim_lh, x

# %%
def build_simpleCNN_model(resolution, n_channels, n_classes):
    """
        Build a simple CNN model with 2 convolutional layers, 2 max pooling layers, 1 fully connected layer and 1 output layer.
        The model is built using the Keras functional API.
        The model is compiled with the Adam optimizer and the categorical cross entropy loss function.
    """
    
    # Define the input shape
    """ input_shape = Input(shape=(resolution, resolution, n_channels))
    x = Conv2D(16, (3, 3), activation='relu')(input_shape) # 32
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(32, (3, 3), activation='relu')(x) # 64
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    x = Conv2D(64, (3, 3), activation='relu')(x) # 64
    x = MaxPooling2D(pool_size=(2, 2))(x) """
    inputs = Input(shape=(resolution, resolution, n_channels))
    x = Conv2D(16, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)

    x = Flatten()(x)
    #x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    output_l = Dense(1, activation="linear", name="lenght")(x)
    output_h = Dense(1, activation="linear", name="height")(x)
    

    # Define the model with the specified input and outputs
    model = Model(inputs=inputs, outputs=[output_l, output_h])
    return model

# %%
# build model
resolution = X_test.shape[1]
n_channels = X_test.shape[3]
n_classes = y_test.shape[1]

battch_size = 32
epochs = 40
validation_split = 0.2
learning_rate = 0.0001

print("resolution: ", resolution)
print("n_channels: ", n_channels)
print("n_classes: ", n_classes)

# build model
model = build_simpleCNN_model(resolution, n_channels, n_classes)

# compile model
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
model.compile(optimizer=optimizer, loss='mse') #, metrics=['mse'])  # Using Mean Squared Error (mse) as the loss
# print model summary
model.summary()


# train model
history = model.fit(x=X_train,
                    y=[y_train[:, 0], y_train[:, 1]],
                    batch_size=battch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=validation_split)
# Out:
# resolution:  320
# n_channels:  2
# n_classes:  2
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 320, 320, 2)]        0         []
#
#  conv2d_6 (Conv2D)           (None, 318, 318, 16)         304       ['input_3[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 159, 159, 16)         0         ['conv2d_6[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 157, 157, 32)         4640      ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 78, 78, 32)           0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 76, 76, 64)           18496     ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 38, 38, 64)           0         ['conv2d_8[0][0]']
#  g2D)
#
#  flatten_4 (Flatten)         (None, 92416)                0         ['max_pooling2d_8[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  1182937   ['flatten_4[0][0]']
#                                                           6
#
#  flatten_5 (Flatten)         (None, 128)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 256)                  33024     ['flatten_5[0][0]']
#
#  lenght (Dense)              (None, 1)                    257       ['dense_5[0][0]']
#
#  height (Dense)              (None, 1)                    257       ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 11886354 (45.34 MB)
# Trainable params: 11886354 (45.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/40
# 2024-01-18 15:57:53.876644: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-01-18 15:57:54.017492: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-18 15:57:54.610733: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-18 15:57:55.378296: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f08992e6120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-18 15:57:55.378343: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-01-18 15:57:55.394336: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1705593475.569936 1582420 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 192/192 [==============================] - 17s 55ms/step - loss: 0.1670 - lenght_loss: 0.0972 - height_loss: 0.0699 - val_loss: 0.0011 - val_lenght_loss: 7.1372e-04 - val_height_loss: 3.9945e-04
# Epoch 2/40
# 192/192 [==============================] - 6s 33ms/step - loss: 9.5438e-04 - lenght_loss: 4.9028e-04 - height_loss: 4.6410e-04 - val_loss: 7.0012e-04 - val_lenght_loss: 3.8705e-04 - val_height_loss: 3.1307e-04
# Epoch 3/40
# 192/192 [==============================] - 6s 34ms/step - loss: 8.0280e-04 - lenght_loss: 4.2973e-04 - height_loss: 3.7307e-04 - val_loss: 7.0438e-04 - val_lenght_loss: 4.5705e-04 - val_height_loss: 2.4733e-04
# Epoch 4/40
# 192/192 [==============================] - 7s 34ms/step - loss: 5.9847e-04 - lenght_loss: 3.0176e-04 - height_loss: 2.9671e-04 - val_loss: 5.7862e-04 - val_lenght_loss: 3.8747e-04 - val_height_loss: 1.9114e-04
# Epoch 5/40
# 192/192 [==============================] - 6s 34ms/step - loss: 4.6825e-04 - lenght_loss: 2.1547e-04 - height_loss: 2.5279e-04 - val_loss: 3.5303e-04 - val_lenght_loss: 2.0056e-04 - val_height_loss: 1.5247e-04
# Epoch 6/40
# 192/192 [==============================] - 7s 36ms/step - loss: 4.6585e-04 - lenght_loss: 2.1791e-04 - height_loss: 2.4795e-04 - val_loss: 6.2866e-04 - val_lenght_loss: 4.7267e-04 - val_height_loss: 1.5600e-04
# Epoch 7/40
# 192/192 [==============================] - 7s 34ms/step - loss: 4.0025e-04 - lenght_loss: 1.7028e-04 - height_loss: 2.2997e-04 - val_loss: 5.4299e-04 - val_lenght_loss: 3.9598e-04 - val_height_loss: 1.4701e-04
# Epoch 8/40
# 192/192 [==============================] - 7s 36ms/step - loss: 4.0346e-04 - lenght_loss: 1.9026e-04 - height_loss: 2.1320e-04 - val_loss: 4.6090e-04 - val_lenght_loss: 3.1870e-04 - val_height_loss: 1.4220e-04
# Epoch 9/40
# 192/192 [==============================] - 7s 35ms/step - loss: 3.6452e-04 - lenght_loss: 1.5684e-04 - height_loss: 2.0768e-04 - val_loss: 2.9590e-04 - val_lenght_loss: 1.6463e-04 - val_height_loss: 1.3127e-04
# Epoch 10/40
# 192/192 [==============================] - 7s 35ms/step - loss: 3.5797e-04 - lenght_loss: 1.5435e-04 - height_loss: 2.0362e-04 - val_loss: 4.2813e-04 - val_lenght_loss: 2.6491e-04 - val_height_loss: 1.6321e-04
# Epoch 11/40
# 192/192 [==============================] - 7s 34ms/step - loss: 3.4936e-04 - lenght_loss: 1.5635e-04 - height_loss: 1.9301e-04 - val_loss: 3.0205e-04 - val_lenght_loss: 1.8218e-04 - val_height_loss: 1.1988e-04
# Epoch 12/40
# 192/192 [==============================] - 7s 34ms/step - loss: 3.8332e-04 - lenght_loss: 1.7936e-04 - height_loss: 2.0396e-04 - val_loss: 8.1010e-04 - val_lenght_loss: 6.0314e-04 - val_height_loss: 2.0696e-04
# Epoch 13/40
# 192/192 [==============================] - 6s 34ms/step - loss: 3.4085e-04 - lenght_loss: 1.5078e-04 - height_loss: 1.9007e-04 - val_loss: 7.4214e-04 - val_lenght_loss: 4.7141e-04 - val_height_loss: 2.7073e-04
# Epoch 14/40
# 192/192 [==============================] - 6s 34ms/step - loss: 4.3488e-04 - lenght_loss: 2.3087e-04 - height_loss: 2.0401e-04 - val_loss: 2.7305e-04 - val_lenght_loss: 1.4611e-04 - val_height_loss: 1.2694e-04
# Epoch 15/40
# 192/192 [==============================] - 6s 34ms/step - loss: 3.0310e-04 - lenght_loss: 1.2683e-04 - height_loss: 1.7627e-04 - val_loss: 3.4401e-04 - val_lenght_loss: 1.9071e-04 - val_height_loss: 1.5330e-04
# Epoch 16/40
# 192/192 [==============================] - 7s 34ms/step - loss: 3.2686e-04 - lenght_loss: 1.4994e-04 - height_loss: 1.7692e-04 - val_loss: 0.0017 - val_lenght_loss: 6.2660e-04 - val_height_loss: 0.0011
# Epoch 17/40
# 192/192 [==============================] - 6s 34ms/step - loss: 3.8281e-04 - lenght_loss: 1.8445e-04 - height_loss: 1.9836e-04 - val_loss: 3.0071e-04 - val_lenght_loss: 1.6752e-04 - val_height_loss: 1.3319e-04
# Epoch 18/40
# 192/192 [==============================] - 7s 36ms/step - loss: 2.9588e-04 - lenght_loss: 1.3931e-04 - height_loss: 1.5657e-04 - val_loss: 2.7169e-04 - val_lenght_loss: 1.6956e-04 - val_height_loss: 1.0214e-04
# Epoch 19/40
# 192/192 [==============================] - 6s 34ms/step - loss: 4.6082e-04 - lenght_loss: 2.5528e-04 - height_loss: 2.0554e-04 - val_loss: 2.3685e-04 - val_lenght_loss: 1.2774e-04 - val_height_loss: 1.0911e-04
# Epoch 20/40
# 192/192 [==============================] - 6s 34ms/step - loss: 2.1786e-04 - lenght_loss: 9.1758e-05 - height_loss: 1.2610e-04 - val_loss: 3.2136e-04 - val_lenght_loss: 2.0058e-04 - val_height_loss: 1.2078e-04
# Epoch 21/40
# 192/192 [==============================] - 6s 34ms/step - loss: 2.3018e-04 - lenght_loss: 1.0080e-04 - height_loss: 1.2938e-04 - val_loss: 2.7528e-04 - val_lenght_loss: 1.5572e-04 - val_height_loss: 1.1956e-04
# Epoch 22/40
# 192/192 [==============================] - 6s 34ms/step - loss: 2.4784e-04 - lenght_loss: 1.2184e-04 - height_loss: 1.2600e-04 - val_loss: 4.0548e-04 - val_lenght_loss: 2.4729e-04 - val_height_loss: 1.5819e-04
# Epoch 23/40
# 192/192 [==============================] - 7s 36ms/step - loss: 2.1999e-04 - lenght_loss: 1.0604e-04 - height_loss: 1.1395e-04 - val_loss: 2.9791e-04 - val_lenght_loss: 1.8579e-04 - val_height_loss: 1.1212e-04
# Epoch 24/40
# 192/192 [==============================] - 6s 33ms/step - loss: 2.1455e-04 - lenght_loss: 1.0927e-04 - height_loss: 1.0529e-04 - val_loss: 3.6483e-04 - val_lenght_loss: 1.8777e-04 - val_height_loss: 1.7705e-04
# Epoch 25/40
# 192/192 [==============================] - 7s 35ms/step - loss: 2.3210e-04 - lenght_loss: 1.3072e-04 - height_loss: 1.0138e-04 - val_loss: 2.5848e-04 - val_lenght_loss: 1.3743e-04 - val_height_loss: 1.2106e-04
# Epoch 26/40
# 192/192 [==============================] - 6s 33ms/step - loss: 2.8102e-04 - lenght_loss: 1.6523e-04 - height_loss: 1.1579e-04 - val_loss: 4.6809e-04 - val_lenght_loss: 2.5763e-04 - val_height_loss: 2.1046e-04
# Epoch 27/40
# 192/192 [==============================] - 6s 33ms/step - loss: 2.9526e-04 - lenght_loss: 1.7553e-04 - height_loss: 1.1973e-04 - val_loss: 2.5168e-04 - val_lenght_loss: 1.3761e-04 - val_height_loss: 1.1407e-04
# Epoch 28/40
# 192/192 [==============================] - 6s 33ms/step - loss: 2.1543e-04 - lenght_loss: 1.1982e-04 - height_loss: 9.5610e-05 - val_loss: 5.0233e-04 - val_lenght_loss: 1.3609e-04 - val_height_loss: 3.6624e-04
# Epoch 29/40
# 192/192 [==============================] - 6s 33ms/step - loss: 1.7545e-04 - lenght_loss: 9.2745e-05 - height_loss: 8.2702e-05 - val_loss: 2.3492e-04 - val_lenght_loss: 1.4839e-04 - val_height_loss: 8.6528e-05
# Epoch 30/40
# 192/192 [==============================] - 7s 35ms/step - loss: 3.6602e-04 - lenght_loss: 2.2435e-04 - height_loss: 1.4167e-04 - val_loss: 3.9089e-04 - val_lenght_loss: 1.7943e-04 - val_height_loss: 2.1145e-04
# Epoch 31/40
# 192/192 [==============================] - 6s 31ms/step - loss: 1.8064e-04 - lenght_loss: 9.6561e-05 - height_loss: 8.4078e-05 - val_loss: 2.9292e-04 - val_lenght_loss: 1.7730e-04 - val_height_loss: 1.1562e-04
# Epoch 32/40
# 192/192 [==============================] - 7s 34ms/step - loss: 1.0199e-04 - lenght_loss: 5.7291e-05 - height_loss: 4.4696e-05 - val_loss: 2.8836e-04 - val_lenght_loss: 1.2913e-04 - val_height_loss: 1.5923e-04
# Epoch 33/40
# 192/192 [==============================] - 6s 34ms/step - loss: 1.5978e-04 - lenght_loss: 1.0100e-04 - height_loss: 5.8786e-05 - val_loss: 2.0888e-04 - val_lenght_loss: 1.2477e-04 - val_height_loss: 8.4109e-05
# Epoch 34/40
# 192/192 [==============================] - 7s 36ms/step - loss: 1.4618e-04 - lenght_loss: 9.2126e-05 - height_loss: 5.4051e-05 - val_loss: 2.1648e-04 - val_lenght_loss: 1.2975e-04 - val_height_loss: 8.6731e-05
# Epoch 35/40
# 192/192 [==============================] - 6s 34ms/step - loss: 1.5396e-04 - lenght_loss: 1.0006e-04 - height_loss: 5.3904e-05 - val_loss: 4.7382e-04 - val_lenght_loss: 3.3973e-04 - val_height_loss: 1.3408e-04
# Epoch 36/40
# 192/192 [==============================] - 6s 34ms/step - loss: 1.0904e-04 - lenght_loss: 6.4958e-05 - height_loss: 4.4078e-05 - val_loss: 3.3908e-04 - val_lenght_loss: 2.1787e-04 - val_height_loss: 1.2121e-04
# Epoch 37/40
# 192/192 [==============================] - 6s 34ms/step - loss: 8.1315e-05 - lenght_loss: 4.7415e-05 - height_loss: 3.3901e-05 - val_loss: 2.0398e-04 - val_lenght_loss: 1.1807e-04 - val_height_loss: 8.5909e-05
# Epoch 38/40
# 192/192 [==============================] - 7s 36ms/step - loss: 1.1000e-04 - lenght_loss: 6.2714e-05 - height_loss: 4.7288e-05 - val_loss: 2.0517e-04 - val_lenght_loss: 1.1937e-04 - val_height_loss: 8.5806e-05
# Epoch 39/40
# 192/192 [==============================] - 6s 34ms/step - loss: 2.7219e-04 - lenght_loss: 1.6897e-04 - height_loss: 1.0322e-04 - val_loss: 4.7553e-04 - val_lenght_loss: 3.1022e-04 - val_height_loss: 1.6531e-04
# Epoch 40/40
# 192/192 [==============================] - 7s 34ms/step - loss: 1.9450e-04 - lenght_loss: 1.1366e-04 - height_loss: 8.0840e-05 - val_loss: 3.5072e-04 - val_lenght_loss: 1.8424e-04 - val_height_loss: 1.6648e-04

# %%
# save model
#model.save("simpleCNN_model.h5")

# %%
# evaluate model
score = model.evaluate(X_test, [y_test[:, 0], y_test[:, 1]], verbose=0)
print(score)
# Out:
# [0.00031153394957073033, 0.0001590075989952311, 0.00015252629236783832]

# %%
# eval regression model
from sklearn.metrics import r2_score

y_pred_l, y_pred_h = model.predict(X_test)
r2_l = r2_score(y_test[:,0], y_pred_l)
r2_h = r2_score(y_test[:,1], y_pred_h)
print("r2 score: ", r2_l, r2_h)

# plot loss and metrics: mse and mae
import matplotlib.pyplot as plt

# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training and validation loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# 60/60 [==============================] - 1s 15ms/step
# r2 score:  0.9969902911156626 0.9860224944751889

# %%
# plot lenght_loss and height_loss during training and validation
plt.plot(history.history['lenght_loss'])
plt.plot(history.history['height_loss'])
plt.plot(history.history['val_lenght_loss'])
plt.plot(history.history['val_height_loss'])
plt.title('Training and validation lenght and height loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['lenght_train', 'height_train', 'lenght_val', 'height_val'], loc='upper left')
plt.show()

# %%
# make a black image with the same shape as X_test[0]
black_image = np.zeros(X_test[0].shape[0])
print(black_image.shape)

# replace the second channel with the black image 
X_test_new = np.copy(X_test)
X_test_new[:, :, :, 1] = black_image

""" x = X_test_new[10]
# plot first and second channel of x
plt.imshow(x[:, :, 0])
plt.show()
plt.imshow(x[:, :, 1])
plt.show()
 """
# Out:
# (320,)
# ' x = X_test_new[10]\n# plot first and second channel of x\nplt.imshow(x[:, :, 0])\nplt.show()\nplt.imshow(x[:, :, 1])\nplt.show()\n '

# %%
y_pred_l_new, y_pred_h_new = model.predict(X_test_new)
r2_l_new = r2_score(y_test[:,0], y_pred_l_new)
r2_h_new = r2_score(y_test[:,1], y_pred_h_new)

print("r2 score: ", r2_l_new, r2_h_new)
# Out:
# 60/60 [==============================] - 1s 15ms/step
# r2 score:  -7.109014187820108 -16.331621485604416

# %%
import matplotlib.pyplot as plt

# Increase overall text size
plt.rcParams.update({'font.size': 12})

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the first scatter plot (length prediction)
axs[0].scatter(y_test[:, 0], y_pred_l, alpha=0.7, edgecolors='w', label='Both Channels')
axs[0].scatter(y_test[:, 0], y_pred_l_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[0].plot([min(y_test[:, 0]), max(y_test[:, 0])], [min(y_test[:, 0]), max(y_test[:, 0])], '--', color='red', linewidth=2)
axs[0].set_title("Length Prediction")
axs[0].set_xlabel("True Length")
axs[0].set_ylabel("Predicted Length")
axs[0].legend()
axs[0].grid(True)

# Plotting the second scatter plot (height prediction)
axs[1].scatter(y_test[:, 1], y_pred_h, alpha=0.7, edgecolors='w', label='Both Channels')
axs[1].scatter(y_test[:, 1], y_pred_h_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[1].plot([min(y_test[:, 1]), max(y_test[:, 1])], [min(y_test[:, 1]), max(y_test[:, 1])], '--', color='red', linewidth=2)
axs[1].set_title("Height Prediction")
axs[1].set_xlabel("True Height")
axs[1].set_ylabel("Predicted Height")
axs[1].legend()
axs[1].grid(True)

# Adjust layout for better visualization
plt.tight_layout()

# Show the plot
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

def eval_tsne_pca(model, x_test, plot=True):
    # Assuming 'model' is your trained regression model and 'data' is your input data
    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[-3].output)
    intermediate_activations = intermediate_layer_model.predict(x_test)

    # Apply t-SNE or PCA
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(intermediate_activations)

    # Visualize t-SNE results
    if plot:
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    # apply PCA
    pca = PCA(n_components=2)
    pca_results = pca.fit_transform(intermediate_activations)

    # Visualize PCA results
    if plot:
        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    return tsne_results, pca_results

tsne_results, pca_results = eval_tsne_pca(model, X_test, plot=True)

# eval for X_test_new
tsne_results, pca_results = eval_tsne_pca(model, X_test_new, plot=True)
# Out:
# 60/60 [==============================] - 1s 14ms/step
# 60/60 [==============================] - 1s 13ms/step
