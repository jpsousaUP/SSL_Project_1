# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation
import numpy as np

# verify if GPU is available
print(tf.test.is_gpu_available())

# set memory growth to true
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Setting memory growth to True for GPU: ", physical_devices[0])
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# dont display much info of tensorflow
tf.get_logger().setLevel('ERROR')
# Out:
# True
# Setting memory growth to True for GPU:  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 2024-02-23 10:39:30.623478: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-23 10:39:30.624261: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-23 10:39:30.624708: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-23 10:39:30.625298: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-23 10:39:30.625737: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-23 10:39:30.626078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 46874 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:07:00.0, compute capability: 8.6

# %%
# Load data
manta_path = "/home/vm/Joao/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_manta.npy"
xiris_path = "/home/vm/Joao/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_xiris.npy"
y_path = "/home/vm/Joao/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_y.npy"
feats_path = "/home/vm/Joao/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_feats.npy"

# load numpy arrays and display shapes
manta = np.load(manta_path)
xiris = np.load(xiris_path)
y = np.load(y_path) # only laser power and velocity
print("manta shape: ", manta.shape)
print("xiris shape: ", xiris.shape)
print("y shape: ", y.shape) # laser power and velocity

feats = np.load(feats_path)
print("feats shape: ", feats.shape) # feats shape:  (100, 2, 2, 2, 2, 2, 2, 2, 2, 2)
# Out:
# manta shape:  (9587, 320, 320)
# xiris shape:  (9587, 320, 320)
# y shape:  (9587, 2)
# feats shape:  (9587, 8)

# %%
# dimensions of MP are the index 1 and 2 of column in feat
dim_lh = feats[:, 1:3]

max_lh = dim_lh.max(axis=0)
# normalize dim_lh based on max value of each column
dim_lh = dim_lh / max_lh

dim_lh
# Out:
# array([[0.        , 0.        ],
#        [0.        , 0.        ],
#        [0.02666667, 0.03797468],
#        ...,
#        [0.87111111, 0.48101266],
#        [0.87111111, 0.48101266],
#        [0.83555556, 0.48101266]])

# %%
# concatenate manta and xiris images with label y_encoded as rows
# concatenate the two inputs (manta and xiris) along rows
# expand the dimension of x to 4D
manta = np.expand_dims(manta, axis=3)
xiris = np.expand_dims(xiris, axis=3)
x = np.concatenate((manta, xiris), axis=3)
y = dim_lh
print("x shape: ", x.shape)
print("y shape: ", y.shape)
# Out:
# x shape:  (9587, 320, 320, 2)
# y shape:  (9587, 2)

# %%
# split data into train and test (manta as input and y as output) with shuffle as true
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=42)
print("x_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("x_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (7669, 320, 320, 2)
# y_train shape:  (7669, 2)
# x_test shape:  (1918, 320, 320, 2)
# y_test shape:  (1918, 2)

# %%
del manta, xiris, y, dim_lh, x

# %%
# import efficientnetBO base model
from tensorflow.keras.applications import EfficientNetB0

# create the base pre-trained model
base_model = EfficientNetB0(input_shape=(320, 320, 1), include_top=False, weights=None) #weights='imagenet')

# %%
# summary of the base model
base_model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 320, 320, 1)          0         ['input_3[0][0]']
#
#  normalization_1 (Normaliza  (None, 320, 320, 1)          3         ['rescaling_1[0][0]']
#  tion)
#
#  stem_conv_pad (ZeroPadding  (None, 321, 321, 1)          0         ['normalization_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 160, 160, 32)         288       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 160, 160, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 160, 160, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 160, 160, 32)         288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 160, 160, 32)         128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 160, 160, 32)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 160, 160, 32)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 160, 160, 16)         512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 160, 160, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block2a_expand_conv (Conv2  (None, 160, 160, 96)         1536      ['block1a_project_bn[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 160, 160, 96)         384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 160, 160, 96)         0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 161, 161, 96)         0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 80, 80, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 80, 80, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 80, 80, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 80, 80, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 80, 80, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 80, 80, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 80, 80, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 80, 80, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 80, 80, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 80, 80, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 80, 80, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 80, 80, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 80, 80, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 80, 80, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 80, 80, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 80, 80, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 80, 80, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 80, 80, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 80, 80, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 80, 80, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 83, 83, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 40, 40, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 40, 40, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 40, 40, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 40, 40, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 40, 40, 40)           5760      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 40, 40, 40)           160       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 40, 40, 240)          9600      ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 40, 40, 240)          960       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 40, 40, 240)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 40, 40, 240)          6000      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 40, 40, 240)          960       ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 40, 40, 240)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 240)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 40, 40, 240)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 40, 40, 40)           9600      ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 40, 40, 40)           160       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 40, 40, 40)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 40, 40, 40)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 40, 40, 240)          9600      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 40, 40, 240)          960       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 40, 40, 240)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 41, 41, 240)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 20, 20, 240)          2160      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 20, 20, 240)          960       ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 20, 20, 240)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 240)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 20, 20, 240)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 20, 20, 80)           19200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 20, 20, 80)           320       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 20, 20, 480)          38400     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 20, 20, 480)          1920      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 20, 20, 480)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 20, 20, 480)          4320      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 20, 20, 480)          1920      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 20, 20, 480)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 480)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 20, 20, 480)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 20, 20, 80)           38400     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 20, 20, 80)           320       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 20, 20, 80)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 20, 20, 80)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 20, 20, 480)          38400     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 20, 20, 480)          1920      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 20, 20, 480)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 20, 20, 480)          4320      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 20, 20, 480)          1920      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 20, 20, 480)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 480)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 20, 20, 480)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 20, 20, 80)           38400     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 20, 20, 80)           320       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 20, 20, 80)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 20, 20, 80)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 20, 20, 480)          38400     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 20, 20, 480)          1920      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 20, 20, 480)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv (DepthwiseC  (None, 20, 20, 480)          12000     ['block5a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5a_bn (BatchNormaliza  (None, 20, 20, 480)          1920      ['block5a_dwconv[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 20, 20, 480)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 480)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 20, 20, 480)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 20, 20, 112)          53760     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 20, 20, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 20, 20, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 20, 20, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 20, 20, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv (DepthwiseC  (None, 20, 20, 672)          16800     ['block5b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5b_bn (BatchNormaliza  (None, 20, 20, 672)          2688      ['block5b_dwconv[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 20, 20, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 20, 20, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 20, 20, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 20, 20, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 20, 20, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 20, 20, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 20, 20, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 20, 20, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 20, 20, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv (DepthwiseC  (None, 20, 20, 672)          16800     ['block5c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5c_bn (BatchNormaliza  (None, 20, 20, 672)          2688      ['block5c_dwconv[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 20, 20, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 20, 20, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 20, 20, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 20, 20, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 20, 20, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 20, 20, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 20, 20, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 20, 20, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 20, 20, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv_pad (ZeroPa  (None, 23, 23, 672)          0         ['block6a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block6a_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block6a_dwconv_pad[0][0]']
#  onv2D)
#
#  block6a_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block6a_dwconv[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 10, 10, 672)          0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
#  block6a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block6a_se_squeeze[0][0]']
#  e)
# ...
#  tion)
#
#  block6b_activation (Activa  (None, 10, 10, 1152)         0         ['block6b_bn[0][0]']
#  tion)
#
#  block6b_se_squeeze (Global  (None, 1152)                 0         ['block6b_activation[0][0]']
#  AveragePooling2D)
#
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
#  block6b_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multipl  (None, 10, 10, 1152)         0         ['block6b_activation[0][0]',
#  y)                                                                  'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv  (None, 10, 10, 192)          221184    ['block6b_se_excite[0][0]']
#  2D)
#
#  block6b_project_bn (BatchN  (None, 10, 10, 192)          768       ['block6b_project_conv[0][0]']
#  ormalization)
#
#  block6b_drop (Dropout)      (None, 10, 10, 192)          0         ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)           (None, 10, 10, 192)          0         ['block6b_drop[0][0]',
#                                                                      'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2  (None, 10, 10, 1152)         221184    ['block6b_add[0][0]']
#  D)
#
#  block6c_expand_bn (BatchNo  (None, 10, 10, 1152)         4608      ['block6c_expand_conv[0][0]']
#  rmalization)
#
#  block6c_expand_activation   (None, 10, 10, 1152)         0         ['block6c_expand_bn[0][0]']
#  (Activation)
#
#  block6c_dwconv (DepthwiseC  (None, 10, 10, 1152)         28800     ['block6c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6c_bn (BatchNormaliza  (None, 10, 10, 1152)         4608      ['block6c_dwconv[0][0]']
#  tion)
#
#  block6c_activation (Activa  (None, 10, 10, 1152)         0         ['block6c_bn[0][0]']
#  tion)
#
#  block6c_se_squeeze (Global  (None, 1152)                 0         ['block6c_activation[0][0]']
#  AveragePooling2D)
#
#  block6c_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6c_se_squeeze[0][0]']
#  e)
#
#  block6c_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multipl  (None, 10, 10, 1152)         0         ['block6c_activation[0][0]',
#  y)                                                                  'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv  (None, 10, 10, 192)          221184    ['block6c_se_excite[0][0]']
#  2D)
#
#  block6c_project_bn (BatchN  (None, 10, 10, 192)          768       ['block6c_project_conv[0][0]']
#  ormalization)
#
#  block6c_drop (Dropout)      (None, 10, 10, 192)          0         ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)           (None, 10, 10, 192)          0         ['block6c_drop[0][0]',
#                                                                      'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2  (None, 10, 10, 1152)         221184    ['block6c_add[0][0]']
#  D)
#
#  block6d_expand_bn (BatchNo  (None, 10, 10, 1152)         4608      ['block6d_expand_conv[0][0]']
#  rmalization)
#
#  block6d_expand_activation   (None, 10, 10, 1152)         0         ['block6d_expand_bn[0][0]']
#  (Activation)
#
#  block6d_dwconv (DepthwiseC  (None, 10, 10, 1152)         28800     ['block6d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6d_bn (BatchNormaliza  (None, 10, 10, 1152)         4608      ['block6d_dwconv[0][0]']
#  tion)
#
#  block6d_activation (Activa  (None, 10, 10, 1152)         0         ['block6d_bn[0][0]']
#  tion)
#
#  block6d_se_squeeze (Global  (None, 1152)                 0         ['block6d_activation[0][0]']
#  AveragePooling2D)
#
#  block6d_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6d_se_squeeze[0][0]']
#  e)
#
#  block6d_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multipl  (None, 10, 10, 1152)         0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 10, 10, 192)          221184    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 10, 10, 192)          768       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 10, 10, 192)          0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 10, 10, 192)          0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 10, 10, 1152)         221184    ['block6d_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 10, 10, 1152)         4608      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 10, 10, 1152)         0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 10, 10, 1152)         10368     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 10, 10, 1152)         4608      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 10, 10, 1152)         0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1152)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 10, 10, 1152)         0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 10, 10, 320)          368640    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 10, 10, 320)          1280      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  top_conv (Conv2D)           (None, 10, 10, 1280)         409600    ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization  (None, 10, 10, 1280)         5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 10, 10, 1280)         0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 4048991 (15.45 MB)
# Trainable params: 4006972 (15.29 MB)
# Non-trainable params: 42019 (164.14 KB)
# __________________________________________________________________________________________________

# %%
def build_simpleCNN_model(resolution, n_channels, n_classes):
    """
        Build a simple CNN model with 2 convolutional layers, 2 max pooling layers, 1 fully connected layer and 1 output layer.
        The model is built using the Keras functional API.
        The model is compiled with the Adam optimizer and the categorical cross entropy loss function.
    """
    
    # Define the input shape

    inputs = Input(shape=(resolution, resolution, n_channels))
 
    x = base_model(inputs)

    x = Flatten()(x)
    #x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    output_l = Dense(1, activation="linear", name="lenght")(x)
    output_h = Dense(1, activation="linear", name="height")(x)
    

    # Define the model with the specified input and outputs
    model = Model(inputs=inputs, outputs=[output_l, output_h])
    return model

# %%
# build model
resolution = X_test.shape[1]
n_channels = X_test.shape[3]-1
n_classes = y_test.shape[1]

battch_size = 32
epochs = 10
validation_split = 0.2
learning_rate = 0.0001

print("resolution: ", resolution)
print("n_channels: ", n_channels)
print("n_classes: ", n_classes)

# build model
model = build_simpleCNN_model(resolution, n_channels, n_classes)

# compile model
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
model.compile(optimizer=optimizer, loss='mse') #, metrics=['mse'])  # Using Mean Squared Error (mse) as the loss
# print model summary
model.summary()


# train model
history = model.fit(
                    # use only the first channel of the input
                    x=[X_train[:, :, :, 0]],
                    y=[y_train[:, 0], y_train[:, 1]],
                    batch_size=battch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=validation_split)
# Out:
# resolution:  320
# n_channels:  1
# n_classes:  2
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  efficientnetb0 (Functional  (None, 10, 10, 1280)         4048991   ['input_4[0][0]']
#  )
#
#  flatten_1 (Flatten)         (None, 128000)               0         ['efficientnetb0[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  3276825   ['flatten_1[0][0]']
#                                                           6
#
#  lenght (Dense)              (None, 1)                    257       ['dense_1[0][0]']
#
#  height (Dense)              (None, 1)                    257       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 36817761 (140.45 MB)
# Trainable params: 36775742 (140.29 MB)
# Non-trainable params: 42019 (164.14 KB)
# __________________________________________________________________________________________________
# Epoch 1/10
# 2024-02-23 10:40:13.875045: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 192/192 [==============================] - 71s 232ms/step - loss: 104.5586 - lenght_loss: 19.9404 - height_loss: 84.6182 - val_loss: 0.1276 - val_lenght_loss: 0.1069 - val_height_loss: 0.0207
# Epoch 2/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.2238 - lenght_loss: 0.1717 - height_loss: 0.0520 - val_loss: 0.0787 - val_lenght_loss: 0.0637 - val_height_loss: 0.0150
# Epoch 3/10
# 192/192 [==============================] - 41s 213ms/step - loss: 0.1327 - lenght_loss: 0.0949 - height_loss: 0.0378 - val_loss: 0.1993 - val_lenght_loss: 0.1702 - val_height_loss: 0.0292
# Epoch 4/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.1073 - lenght_loss: 0.0755 - height_loss: 0.0318 - val_loss: 0.0566 - val_lenght_loss: 0.0406 - val_height_loss: 0.0159
# Epoch 5/10
# 192/192 [==============================] - 41s 215ms/step - loss: 0.0739 - lenght_loss: 0.0478 - height_loss: 0.0261 - val_loss: 0.0503 - val_lenght_loss: 0.0312 - val_height_loss: 0.0190
# Epoch 6/10
# 192/192 [==============================] - 41s 216ms/step - loss: 0.0688 - lenght_loss: 0.0453 - height_loss: 0.0235 - val_loss: 0.0485 - val_lenght_loss: 0.0282 - val_height_loss: 0.0203
# Epoch 7/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.0536 - lenght_loss: 0.0347 - height_loss: 0.0189 - val_loss: 0.0441 - val_lenght_loss: 0.0290 - val_height_loss: 0.0151
# Epoch 8/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.0454 - lenght_loss: 0.0297 - height_loss: 0.0157 - val_loss: 0.0361 - val_lenght_loss: 0.0178 - val_height_loss: 0.0183
# Epoch 9/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.0573 - lenght_loss: 0.0448 - height_loss: 0.0125 - val_loss: 0.0400 - val_lenght_loss: 0.0305 - val_height_loss: 0.0095
# Epoch 10/10
# 192/192 [==============================] - 41s 214ms/step - loss: 0.0380 - lenght_loss: 0.0278 - height_loss: 0.0102 - val_loss: 0.1057 - val_lenght_loss: 0.0963 - val_height_loss: 0.0094

# %%
# save model
#model.save("simpleCNN_model.h5")

# %%
# evaluate model
score = model.evaluate(X_test[:, :, :, 0], [y_test[:, 0], y_test[:, 1]], verbose=0)
print(score)
# Out:
# [0.10465341806411743, 0.09687316417694092, 0.007780259009450674]

# %%
# eval regression model
from sklearn.metrics import r2_score

y_pred_l, y_pred_h = model.predict(X_test[:, :, :, 0])
r2_l = r2_score(y_test[:,0], y_pred_l)
r2_h = r2_score(y_test[:,1], y_pred_h)
print("r2 score: ", r2_l, r2_h)

# plot loss and metrics: mse and mae
import matplotlib.pyplot as plt

# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training and validation loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# 60/60 [==============================] - 4s 44ms/step
# r2 score:  -0.6846427880341621 0.35636545762996163

# %%
# plot lenght_loss and height_loss during training and validation
plt.plot(history.history['lenght_loss'])
plt.plot(history.history['height_loss'])
plt.plot(history.history['val_lenght_loss'])
plt.plot(history.history['val_height_loss'])
plt.title('Training and validation lenght and height loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['lenght_train', 'height_train', 'lenght_val', 'height_val'], loc='upper left')
plt.show()

# %%
# make a black image with the same shape as X_test[0]
black_image = np.zeros(X_test[0].shape[0])
print(black_image.shape)

# replace the second channel with the black image 
X_test_new = np.copy(X_test)
X_test_new[:, :, :, 1] = black_image

""" x = X_test_new[10]
# plot first and second channel of x
plt.imshow(x[:, :, 0])
plt.show()
plt.imshow(x[:, :, 1])
plt.show()
 """
# Out:
# (320,)
# ' x = X_test_new[10]\n# plot first and second channel of x\nplt.imshow(x[:, :, 0])\nplt.show()\nplt.imshow(x[:, :, 1])\nplt.show()\n '

# %%
y_pred_l_new, y_pred_h_new = model.predict(X_test_new)
r2_l_new = r2_score(y_test[:,0], y_pred_l_new)
r2_h_new = r2_score(y_test[:,1], y_pred_h_new)

print("r2 score: ", r2_l_new, r2_h_new)
# Out:
# 60/60 [==============================] - 4s 49ms/step
# r2 score:  -1.859436423924222 -3.9407149528489533

# %%
import matplotlib.pyplot as plt

# Increase overall text size
plt.rcParams.update({'font.size': 12})

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the first scatter plot (length prediction)
axs[0].scatter(y_test[:, 0], y_pred_l, alpha=0.7, edgecolors='w', label='Both Channels')
axs[0].scatter(y_test[:, 0], y_pred_l_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[0].plot([min(y_test[:, 0]), max(y_test[:, 0])], [min(y_test[:, 0]), max(y_test[:, 0])], '--', color='red', linewidth=2)
axs[0].set_title("Length Prediction")
axs[0].set_xlabel("True Length")
axs[0].set_ylabel("Predicted Length")
axs[0].legend()
axs[0].grid(True)

# Plotting the second scatter plot (height prediction)
axs[1].scatter(y_test[:, 1], y_pred_h, alpha=0.7, edgecolors='w', label='Both Channels')
axs[1].scatter(y_test[:, 1], y_pred_h_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[1].plot([min(y_test[:, 1]), max(y_test[:, 1])], [min(y_test[:, 1]), max(y_test[:, 1])], '--', color='red', linewidth=2)
axs[1].set_title("Height Prediction")
axs[1].set_xlabel("True Height")
axs[1].set_ylabel("Predicted Height")
axs[1].legend()
axs[1].grid(True)

# Adjust layout for better visualization
plt.tight_layout()

# Show the plot
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

def eval_tsne_pca(model, x_test, plot=True):
    # Assuming 'model' is your trained regression model and 'data' is your input data
    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[-3].output)
    intermediate_activations = intermediate_layer_model.predict(x_test)

    # Apply t-SNE or PCA
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(intermediate_activations)

    # Visualize t-SNE results
    if plot:
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    # apply PCA
    pca = PCA(n_components=2)
    pca_results = pca.fit_transform(intermediate_activations)

    # Visualize PCA results
    if plot:
        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    return tsne_results, pca_results

tsne_results, pca_results = eval_tsne_pca(model, X_test, plot=True)

# eval for X_test_new
tsne_results, pca_results = eval_tsne_pca(model, X_test_new, plot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 31
#      27         plt.show()
#      29     return tsne_results, pca_results
# ---> 31 tsne_results, pca_results = eval_tsne_pca(model, X_test, plot=True)
#      33 # eval for X_test_new
#      34 tsne_results, pca_results = eval_tsne_pca(model, X_test_new, plot=True)
#
# Cell In[33], line 7, in eval_tsne_pca(model, x_test, plot)
#       4 def eval_tsne_pca(model, x_test, plot=True):
#       5     # Assuming 'model' is your trained regression model and 'data' is your input data
#       6     intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[-3].output)
# ----> 7     intermediate_activations = intermediate_layer_model.predict(x_test)
#       9     # Apply t-SNE or PCA
#      10     tsne = TSNE(n_components=2, random_state=42)
#
# File ~/Joao/ssl/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_file332d1ubh.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/vm/Joao/ssl/lib/python3.10/site-packages/keras/src/engine/input_spec.py", line 280, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'efficientnetb0' (type Functional).
#
#     Input 0 of layer "stem_conv" is incompatible with the layer: expected axis -1 of input shape to have value 1, but received input with shape (None, 321, 321, 2)
#
#     Call arguments received by layer 'efficientnetb0' (type Functional):
#       • inputs=tf.Tensor(shape=(None, 320, 320, 2), dtype=float32)
#       • training=False
#       • mask=None
