# %%
# !nvidia-smi
# Out:
# Wed Jan 24 15:57:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A6000               Off | 00000000:07:00.0 Off |                  Off |
# | 34%   48C    P0              69W / 300W |      0MiB / 49140MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#-*- coding: utf-8 -*-

import tensorflow as tf
# dont display much info of tensorflow
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any level you prefer

# limit gpu memory usage only as much as needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
        print("Setting memory growth to True for GPU: ", gpu)
        tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print("Physical GPUs: ", len(gpus), "Logical GPUs: ", len(logical_gpus))
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.layers import Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Activation, GlobalAveragePooling2D, Concatenate, Add, AveragePooling2D
import numpy as np

import matplotlib.pyplot as plt
# Out:
# 2024-01-24 15:57:41.193901: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-24 15:57:41.813630: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-24 15:57:41.813964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-24 15:57:41.919157: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-24 15:57:42.119943: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-24 15:57:44.332723: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-24 15:57:47.106248: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.340921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.341322: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.344510: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.344850: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.345089: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.466619: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.466851: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.466986: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-24 15:57:47.467083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46874 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:07:00.0, compute capability: 8.6
# Setting memory growth to True for GPU:  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Physical GPUs:  1 Logical GPUs:  1

# %%
# Load data
manta_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_manta.npy"
xiris_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_xiris.npy"
y_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_y.npy"
feats_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_feats.npy"

# load numpy arrays and display shapes
manta = np.load(manta_path)
xiris = np.load(xiris_path)
params = np.load(y_path)
print("manta shape: ", manta.shape)
print("xiris shape: ", xiris.shape)
feats = np.load(feats_path)
print("feats shape: ", feats.shape)



# use laser power and velocity as labels
params = params[:, :2]
print("y shape: ", params.shape)

#y = np.concatenate((params, feats[:, 1:3]), axis=1) # L, H
#print("y shape: ", y.shape)

params_max = np.max(params, axis=0)
y = params / params_max

# print max of each column
print("max of each column: ", params_max)

feats = feats[:, 1:3] # remove laser power and velocity

feats_max = np.max(feats, axis=0)
feats = feats / feats_max

print("feats max: ", feats_max)
# Out:
# manta shape:  (9587, 320, 320)
# xiris shape:  (9587, 320, 320)
# feats shape:  (9587, 8)
# y shape:  (9587, 2)
# max of each column:  [2750   15]
# feats max:  [232. 159.]

# %%
# divide data into train and test sets
train_split = 0.8
# randomize data with seed
np.random.seed(42)
indices = np.arange(len(y))

# shuffle indices
np.random.shuffle(indices)

manta = manta[indices]
xiris = xiris[indices]
y = y[indices]
feats = feats[indices]

# split data
train_samples = int(train_split * len(y))
train_manta = manta[:train_samples]
train_xiris = xiris[:train_samples]
train_y = y[:train_samples]
train_feats = feats[:train_samples]

test_manta = manta[train_samples:]
test_xiris = xiris[train_samples:]
test_y = y[train_samples:]
test_feats = feats[train_samples:]

# %%
# create a function to encode y
def encode_one_column(y):
    # create a new array of zeros with the same shape as y
    encoded_y = np.zeros(y.shape)
    # get the unique values in y
    unique_values = np.unique(y)
    # loop through the unique values
    for i, value in enumerate(unique_values):
        # find the indices where y equals the unique value
        indices = np.where(y == value)
        # set the indices in encoded_y to i
        encoded_y[indices] = i
    return encoded_y

# create new array to store encoded y
encoded_y = np.zeros(y.shape)
# loop through each column in y and encode it
for i in range(y.shape[1]):
    encoded_y[:, i] = encode_one_column(y[:, i])
    
# convert to int
encoded_y = encoded_y.astype(int)

# %%
train_encoded_y = encoded_y[:train_samples]

# %%
# crate pairs
def create_pairs_2_labels(manta, xiris, y_encoded, feats):
    # set seed
    np.random.seed(42)
        
    pairs = []
    labels = []
    features = []
    
    # define numclasses with the same columns as y_encoded
    numclasses = np.zeros(y_encoded.shape[1], dtype=int)

    for i in range(y_encoded.shape[1]):
        unique_values, unique_indices = np.unique(y_encoded[:, i], return_inverse=True)
        numclasses[i] = len(unique_values)
    
    # creade idx1 and idx2
    idx1 = [np.where(y_encoded==i)[0] for i in range(numclasses[0])]
    idx2  = [np.where(y_encoded==i)[0] for i in range(numclasses[1])]

    for idxA in range(len(y_encoded)):
        # grab the current image and label belonging to the current iteration
        currentImage = manta[idxA]
        label = y_encoded[idxA]
        p1 = label[0]
        v1 = label[1]
        p2 = np.random.choice(np.delete(np.arange(numclasses[0]), p1))
        v2 = np.random.choice(np.delete(np.arange(numclasses[1]), v1))

        # randomly pick an image that belongs to the same class label
        idxB = np.random.choice(np.intersect1d(idx1[p1], idx2[v1])) #np.random.choice(idx[p1][v1])
        x11 = xiris[idxB]
        # prepare a positive pair and update the images and labels lists, respectively
        pairs.append([currentImage, x11])
        labels.append([p1, v1, p1, v1])
        features.append([feats[idxA][0], feats[idxA][1], feats[idxB][0], feats[idxB][1]])

        idxC = np.random.choice(np.intersect1d(idx1[p2], idx2[v1]))
        x21 = xiris[idxC]
        pairs.append([currentImage, x21])
        labels.append([p1, v1, p2, v1])
        features.append([feats[idxA][0], feats[idxA][1], feats[idxC][0], feats[idxC][1]])   
            
        idxD = np.random.choice(np.intersect1d(idx1[p1], idx2[v2]))
        x12 = xiris[idxD]
        pairs.append([currentImage, x12])
        labels.append([p1, v1, p1, v2])
        features.append([feats[idxA][0], feats[idxA][1], feats[idxD][0], feats[idxD][1]])
        
        idxE = np.random.choice(np.intersect1d(idx1[p2], idx2[v2]))
        x22 = xiris[idxE]
        pairs.append([currentImage, x22])
        labels.append([p1, v1, p2, v2])
        features.append([feats[idxA][0], feats[idxA][1], feats[idxE][0], feats[idxE][1]])
    

        if idxA % 1000 == 0:
            print(f"Creating pairs for image {idxA}/{len(y_encoded)}, Completed {int(idxA/len(y_encoded)*100)}%")
    
    return np.array(pairs), np.array(labels), np.array(features)

                                                                                             
# create pairs
pairs, labels, features = create_pairs_2_labels(train_manta, train_xiris, train_encoded_y, train_feats)
print("pairs shape: ", pairs.shape)
print("labels shape: ", labels.shape)
# Out:
# Creating pairs for image 0/7669, Completed 0%
# Creating pairs for image 1000/7669, Completed 13%
# Creating pairs for image 2000/7669, Completed 26%
# Creating pairs for image 3000/7669, Completed 39%
# Creating pairs for image 4000/7669, Completed 52%
# Creating pairs for image 5000/7669, Completed 65%
# Creating pairs for image 6000/7669, Completed 78%
# Creating pairs for image 7000/7669, Completed 91%
# pairs shape:  (30676, 2, 320, 320)
# labels shape:  (30676, 4)

# %%
""" from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(pairs, labels, test_size=0.2, random_state=42, shuffle=True)

del pairs, labels

# print shapes
print("X_train shape: ", X_train.shape, "y_train shape: ", y_train.shape)
print("X_test shape: ", X_test.shape, "y_test shape: ", y_test.shape) """
# Out:
# ' from sklearn.model_selection import train_test_split\n\nX_train, X_test, y_train, y_test = train_test_split(pairs, labels, test_size=0.2, random_state=42, shuffle=True)\n\ndel pairs, labels\n\n# print shapes\nprint("X_train shape: ", X_train.shape, "y_train shape: ", y_train.shape)\nprint("X_test shape: ", X_test.shape, "y_test shape: ", y_test.shape) '

# %%
def create_encoder(input_shape=(320, 320, 1)):
    inputs = Input(shape=input_shape)
    
    x = Conv2D(16, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    
    #x = Dense(128, activation='relu')(x)
    model = Model(inputs=inputs, outputs=x)
    return model

# add projection head
def add_projection_head(input_shape, encoder, embedding_dim):
    inputs = Input(shape=input_shape)
    features = encoder(inputs)
    #features = Dense(128, activation='relu')(features)
    model = Model(inputs=inputs, outputs=features)  
    return model

input_shape = (320, 320, 1)
embedding_dim= 128
batch_size = 64
epochs = 40
validation_split = 0.2
learning_rate = 0.0001

encoder = create_encoder(input_shape)
encoder_with_projection_head = add_projection_head(input_shape, encoder, embedding_dim)

manta = Input(shape=input_shape)
xiris = Input(shape=input_shape)

manta_encoded = encoder_with_projection_head(manta)
xiris_encoded = encoder_with_projection_head(xiris)

manta_outputs_p = Dense(embedding_dim, activation='relu')(manta_encoded)
manta_outputs_v = Dense(embedding_dim, activation='relu')(manta_encoded)

xiris_outputs_p = Dense(embedding_dim, activation='relu')(xiris_encoded)
xiris_outputs_v = Dense(embedding_dim, activation='relu')(xiris_encoded)

reg_manta_p = tf.keras.layers.Dense(1, activation="linear")(manta_outputs_p) 
reg_manta_v = tf.keras.layers.Dense(1, activation="linear")(manta_outputs_v) 

reg_xiris_p = tf.keras.layers.Dense(1, activation="linear")(xiris_outputs_p) 
reg_xiris_v = tf.keras.layers.Dense(1, activation="linear")(xiris_outputs_v) 

siamese_net = tf.keras.Model(inputs=[manta, xiris], outputs=[manta_outputs_p, manta_outputs_v, xiris_outputs_p, xiris_outputs_v, reg_manta_p, reg_manta_v, reg_xiris_p, reg_xiris_v])

siamese_net.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  input_4 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_1 (Functional)        (None, 92416)                23296     ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  dense (Dense)               (None, 128)                  1182937   ['model_1[0][0]']
#                                                           6
#
#  dense_1 (Dense)             (None, 128)                  1182937   ['model_1[0][0]']
#                                                           6
#
#  dense_2 (Dense)             (None, 128)                  1182937   ['model_1[1][0]']
#                                                           6
#
#  dense_3 (Dense)             (None, 128)                  1182937   ['model_1[1][0]']
#                                                           6
#
#  dense_4 (Dense)             (None, 1)                    129       ['dense[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    129       ['dense_1[0][0]']
#
#  dense_6 (Dense)             (None, 1)                    129       ['dense_2[0][0]']
#
#  dense_7 (Dense)             (None, 1)                    129       ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 47341316 (180.59 MB)
# Trainable params: 47341316 (180.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
class SiameseModel(Model):
    """
        The Siamese Network model with a custom training and testing loops.
        Computes the contrastive loss using the two embeddings produced by the Siamese Network.
    """
    def __init__(self, siamese_network):
        super().__init__()
        self.siamese_network = siamese_network
        self.margin = 1.0
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")


    def call(self, inputs):
        return self.siamese_network(inputs)

    def train_step(self, data):
        # Unpack the data
        X, y = data  
        #print(y)
        
        with tf.GradientTape() as tape:
            y_pred = self.siamese_network(X) # Forward pass
            #print(y_pred)
            # compute loss
            loss = self.contrastive_loss_PV(y_true=y, y_pred=y_pred)
            loss_reg_manta_p = tf.keras.losses.MeanSquaredError()(y[:, 0], y_pred[4])
            loss_reg_manta_v = tf.keras.losses.MeanSquaredError()(y[:, 1], y_pred[5])
            loss_reg_xiris_p = tf.keras.losses.MeanSquaredError()(y[:, 2], y_pred[6])
            loss_reg_xiris_v = tf.keras.losses.MeanSquaredError()(y[:, 3], y_pred[7])
            loss = loss + loss_reg_manta_p + loss_reg_manta_v + loss_reg_xiris_p + loss_reg_xiris_v
            
        # Storing the gradients of the loss function with respect to the weights/parameters.
        gradients = tape.gradient(loss, self.siamese_network.trainable_weights)

        # Applying the gradients on the model using the specified optimizer
        self.optimizer.apply_gradients(
            zip(gradients, self.siamese_network.trainable_weights)
        )

        # Let's update and return the training loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data): # model.evaluate() stores the losses and metrics in a list
        # Unpack the data
        X, y = data
        
        # Compute predictions
        y_pred = self.siamese_network(X, training=False)
        # The loss is computed on the test set
        loss = self.contrastive_loss_PV(y_true=y, y_pred=y_pred)
        loss_reg_manta_p = tf.keras.losses.MeanSquaredError()(y[:, 0], y_pred[4])
        loss_reg_manta_v = tf.keras.losses.MeanSquaredError()(y[:, 1], y_pred[5])
        loss_reg_xiris_p = tf.keras.losses.MeanSquaredError()(y[:, 2], y_pred[6])
        loss_reg_xiris_v = tf.keras.losses.MeanSquaredError()(y[:, 3], y_pred[7])
        loss = loss + loss_reg_manta_p + loss_reg_manta_v + loss_reg_xiris_p + loss_reg_xiris_v
        
        # Update the loss metric
        self.loss_tracker.update_state(loss)
    
        return {"loss": self.loss_tracker.result()}
    

    def contrastive_loss_PV(self, y_true, y_pred):
        # Extract embeddings
        #p1, v1, p2, v2, _ = tf.split(y_pred, num_or_size_splits=[128, 128, 128, 128], axis=1)
        # Extract embeddings
        p1, v1, p2, v2 = y_pred[0], y_pred[1], y_pred[2], y_pred[3]

        # Calculate distances
        distance_p = tf.reduce_sum(tf.square(p1 - p2), axis=1, keepdims=True)
        distance_v = tf.reduce_sum(tf.square(v1 - v2), axis=1, keepdims=True)
        
        # convert to float32
        distance_p = tf.cast(distance_p, dtype=tf.float32)
        distance_v = tf.cast(distance_v, dtype=tf.float32)
        
        # squeeze distance_p and distance_v
        distance_p = tf.squeeze(distance_p, axis=-1)
        distance_v = tf.squeeze(distance_v, axis=-1)

        # Convert y_true to float32
        y_true = tf.cast(y_true, dtype=tf.float32)
        # Ensure margin has the same data type as distance_p and distance_v
        margin = tf.cast(self.margin, dtype=tf.float32)

        # Extract true labels for each task
        y_true_p = tf.cast(tf.not_equal(y_true[:, 0], y_true[:, 2]), tf.float32)
        y_true_v = tf.cast(tf.not_equal(y_true[:, 1], y_true[:, 3]), tf.float32)
        
        square_pred_p = tf.square(distance_p)
        margin_square_p = tf.square(tf.maximum(margin - distance_p, 0))
        loss_p = tf.reduce_mean((1 - y_true_p) * square_pred_p + (y_true_p) * margin_square_p)
        
        square_pred_v = tf.square(distance_v)
        margin_square_v = tf.square(tf.maximum(margin - distance_v, 0))
        loss_v = tf.reduce_mean((1 - y_true_v) * square_pred_v + (y_true_v) * margin_square_v)

        # Combine the losses
        combined_loss = loss_p + loss_v

        return combined_loss

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker]

# %%
# create siamese model
siamese_model = SiameseModel(siamese_net)
# compile model
siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))
# fit model
siamese_model.fit(
    x=[pairs[:, 0], pairs[:, 1]], 
    y=labels,
    batch_size=batch_size, 
    epochs=epochs,
    validation_split=validation_split,
)
# Out:
# Epoch 1/40
# 2024-01-24 15:59:16.006147: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-01-24 15:59:16.427144: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-24 15:59:17.874047: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-24 15:59:18.858316: I external/local_xla/xla/service/service.cc:168] XLA service 0x7efb1a18a3a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-24 15:59:18.858369: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-01-24 15:59:18.891225: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706111959.131361    1654 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 384/384 [==============================] - 53s 111ms/step - loss: 2.5356 - val_loss: 2.0335
# Epoch 2/40
# 384/384 [==============================] - 29s 77ms/step - loss: 1.8340 - val_loss: 1.7112
# Epoch 3/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.5890 - val_loss: 1.5306
# Epoch 4/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.4634 - val_loss: 1.4262
# Epoch 5/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.3880 - val_loss: 1.3868
# Epoch 6/40
# 384/384 [==============================] - 30s 78ms/step - loss: 1.3266 - val_loss: 1.3327
# Epoch 7/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.2880 - val_loss: 1.3146
# Epoch 8/40
# 384/384 [==============================] - 30s 79ms/step - loss: 1.2569 - val_loss: 1.2915
# Epoch 9/40
# 384/384 [==============================] - 31s 80ms/step - loss: 1.2347 - val_loss: 1.2595
# Epoch 10/40
# 384/384 [==============================] - 30s 78ms/step - loss: 1.2053 - val_loss: 1.2403
# Epoch 11/40
# 384/384 [==============================] - 31s 82ms/step - loss: 1.1892 - val_loss: 1.2518
# Epoch 12/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.1740 - val_loss: 1.2611
# Epoch 13/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.1570 - val_loss: 1.2384
# Epoch 14/40
# 384/384 [==============================] - 29s 77ms/step - loss: 1.1470 - val_loss: 1.2314
# Epoch 15/40
# 384/384 [==============================] - 29s 75ms/step - loss: 1.1334 - val_loss: 1.2631
# Epoch 16/40
# 384/384 [==============================] - 29s 75ms/step - loss: 1.1268 - val_loss: 1.2306
# Epoch 17/40
# 384/384 [==============================] - 32s 82ms/step - loss: 1.1180 - val_loss: 1.2299
# Epoch 18/40
# 384/384 [==============================] - 29s 75ms/step - loss: 1.1074 - val_loss: 1.2118
# Epoch 19/40
# 384/384 [==============================] - 31s 82ms/step - loss: 1.1020 - val_loss: 1.2132
# Epoch 20/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.0941 - val_loss: 1.2088
# Epoch 21/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.0853 - val_loss: 1.2236
# Epoch 22/40
# 384/384 [==============================] - 29s 77ms/step - loss: 1.0792 - val_loss: 1.2103
# Epoch 23/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.0746 - val_loss: 1.2084
# Epoch 24/40
# 384/384 [==============================] - 29s 75ms/step - loss: 1.0700 - val_loss: 1.2180
# Epoch 25/40
# 384/384 [==============================] - 29s 77ms/step - loss: 1.0629 - val_loss: 1.2603
# Epoch 26/40
# 384/384 [==============================] - 31s 80ms/step - loss: 1.0595 - val_loss: 1.2135
# Epoch 27/40
# 384/384 [==============================] - 31s 80ms/step - loss: 1.0541 - val_loss: 1.2142
# Epoch 28/40
# 384/384 [==============================] - 29s 77ms/step - loss: 1.0497 - val_loss: 1.2187
# Epoch 29/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.0446 - val_loss: 1.2337
# Epoch 30/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.0403 - val_loss: 1.2231
# Epoch 31/40
# 384/384 [==============================] - 30s 78ms/step - loss: 1.0379 - val_loss: 1.2302
# Epoch 32/40
# 384/384 [==============================] - 29s 76ms/step - loss: 1.0352 - val_loss: 1.2310
# Epoch 33/40
# 384/384 [==============================] - 32s 83ms/step - loss: 1.0330 - val_loss: 1.2226
# Epoch 34/40
# 384/384 [==============================] - 33s 85ms/step - loss: 1.0259 - val_loss: 1.2195
# Epoch 35/40
# 384/384 [==============================] - 33s 85ms/step - loss: 1.0224 - val_loss: 1.2377
# Epoch 36/40
# 384/384 [==============================] - 33s 85ms/step - loss: 1.0193 - val_loss: 1.2388
# Epoch 37/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.0176 - val_loss: 1.2383
# Epoch 38/40
# 384/384 [==============================] - 30s 78ms/step - loss: 1.0102 - val_loss: 1.2323
# Epoch 39/40
# 384/384 [==============================] - 30s 77ms/step - loss: 1.0102 - val_loss: 1.2319
# Epoch 40/40
# 384/384 [==============================] - 30s 78ms/step - loss: 1.0046 - val_loss: 1.2375

# %%
# plot history
plt.plot(siamese_model.history.history['loss'], label='train loss')
plt.plot(siamese_model.history.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# %%
""" for i, layer in enumerate(siamese_model.siamese_network.layers):
    print(i, layer.name) 
    
siamese_model.siamese_network.inputs[0]"""
# Out:
# ' for i, layer in enumerate(siamese_model.siamese_network.layers):\n    print(i, layer.name) \n    \nsiamese_model.siamese_network.inputs[0]'

# %%
inputs = Input(shape=(320, 320, 1))

new_model = tf.keras.Model(inputs=siamese_model.siamese_network.inputs[0], outputs=[siamese_model.siamese_network.layers[3].output, siamese_model.siamese_network.layers[4].output])
new_model.summary()

# set weights of new model 
for layer in new_model.layers:
    layer.set_weights(siamese_model.siamese_network.get_layer(layer.name).get_weights())
    print(layer.name, "weights set")
    layer.trainable = False
    

x = new_model(inputs)
# merge the last 2 layers in a single layer
x = layers.concatenate(x)
# add a two regression heads
x = Dense(128, activation='relu')(x)

output_l = Dense(1, activation="linear", name="lenght")(x)
output_h = Dense(1, activation="linear", name="height")(x)

model_3 = Model(inputs=inputs, outputs=[output_l, output_h])
model_3.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_1 (Functional)        (None, 92416)                23296     ['input_3[0][0]']
#
#  dense (Dense)               (None, 128)                  1182937   ['model_1[0][0]']
#                                                           6
#
#  dense_1 (Dense)             (None, 128)                  1182937   ['model_1[0][0]']
#                                                           6
#
# ==================================================================================================
# Total params: 23682048 (90.34 MB)
# Trainable params: 23682048 (90.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# input_3 weights set
# model_1 weights set
# dense weights set
# dense_1 weights set
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_3 (Functional)        [(None, 128),                2368204   ['input_5[0][0]']
#                               (None, 128)]                8
#
#  concatenate (Concatenate)   (None, 256)                  0         ['model_3[0][0]',
#                                                                      'model_3[0][1]']
#
#  dense_8 (Dense)             (None, 128)                  32896     ['concatenate[0][0]']
#
#  lenght (Dense)              (None, 1)                    129       ['dense_8[0][0]']
#
#  height (Dense)              (None, 1)                    129       ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 23715202 (90.47 MB)
# Trainable params: 33154 (129.51 KB)
# Non-trainable params: 23682048 (90.34 MB)
# __________________________________________________________________________________________________

# %%
# fit model
learning_rate = 0.0001
model_3.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='mse')

batch_size = 64
epochs = 40

history = model_3.fit(x=train_manta,
            y=[train_feats[:, 0], train_feats[:, 1]], #train_feats[]
            #y=y_train[:, 2:], # L, H
            batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/40
# 96/96 [==============================] - 7s 63ms/step - loss: 0.2620 - lenght_loss: 0.1715 - height_loss: 0.0905 - val_loss: 0.0682 - val_lenght_loss: 0.0430 - val_height_loss: 0.0253
# Epoch 2/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0412 - lenght_loss: 0.0250 - height_loss: 0.0162 - val_loss: 0.0281 - val_lenght_loss: 0.0179 - val_height_loss: 0.0102
# Epoch 3/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0231 - lenght_loss: 0.0146 - height_loss: 0.0085 - val_loss: 0.0190 - val_lenght_loss: 0.0132 - val_height_loss: 0.0058
# Epoch 4/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0166 - lenght_loss: 0.0113 - height_loss: 0.0053 - val_loss: 0.0147 - val_lenght_loss: 0.0108 - val_height_loss: 0.0039
# Epoch 5/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0137 - lenght_loss: 0.0098 - height_loss: 0.0039 - val_loss: 0.0130 - val_lenght_loss: 0.0098 - val_height_loss: 0.0031
# Epoch 6/40
# 96/96 [==============================] - 3s 34ms/step - loss: 0.0124 - lenght_loss: 0.0091 - height_loss: 0.0033 - val_loss: 0.0122 - val_lenght_loss: 0.0094 - val_height_loss: 0.0028
# Epoch 7/40
# 96/96 [==============================] - 3s 33ms/step - loss: 0.0119 - lenght_loss: 0.0088 - height_loss: 0.0031 - val_loss: 0.0118 - val_lenght_loss: 0.0092 - val_height_loss: 0.0027
# Epoch 8/40
# 96/96 [==============================] - 3s 34ms/step - loss: 0.0115 - lenght_loss: 0.0086 - height_loss: 0.0029 - val_loss: 0.0116 - val_lenght_loss: 0.0091 - val_height_loss: 0.0026
# Epoch 9/40
# 96/96 [==============================] - 3s 33ms/step - loss: 0.0113 - lenght_loss: 0.0085 - height_loss: 0.0028 - val_loss: 0.0114 - val_lenght_loss: 0.0089 - val_height_loss: 0.0025
# Epoch 10/40
# 96/96 [==============================] - 3s 34ms/step - loss: 0.0111 - lenght_loss: 0.0083 - height_loss: 0.0028 - val_loss: 0.0112 - val_lenght_loss: 0.0087 - val_height_loss: 0.0025
# Epoch 11/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0109 - lenght_loss: 0.0082 - height_loss: 0.0027 - val_loss: 0.0111 - val_lenght_loss: 0.0087 - val_height_loss: 0.0024
# Epoch 12/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0107 - lenght_loss: 0.0081 - height_loss: 0.0027 - val_loss: 0.0109 - val_lenght_loss: 0.0086 - val_height_loss: 0.0024
# Epoch 13/40
# 96/96 [==============================] - 3s 34ms/step - loss: 0.0106 - lenght_loss: 0.0080 - height_loss: 0.0026 - val_loss: 0.0107 - val_lenght_loss: 0.0084 - val_height_loss: 0.0023
# Epoch 14/40
# 96/96 [==============================] - 3s 33ms/step - loss: 0.0104 - lenght_loss: 0.0078 - height_loss: 0.0026 - val_loss: 0.0106 - val_lenght_loss: 0.0083 - val_height_loss: 0.0023
# Epoch 15/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0103 - lenght_loss: 0.0078 - height_loss: 0.0025 - val_loss: 0.0105 - val_lenght_loss: 0.0082 - val_height_loss: 0.0023
# Epoch 16/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0102 - lenght_loss: 0.0077 - height_loss: 0.0025 - val_loss: 0.0103 - val_lenght_loss: 0.0081 - val_height_loss: 0.0022
# Epoch 17/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0100 - lenght_loss: 0.0075 - height_loss: 0.0025 - val_loss: 0.0103 - val_lenght_loss: 0.0081 - val_height_loss: 0.0022
# Epoch 18/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0099 - lenght_loss: 0.0075 - height_loss: 0.0025 - val_loss: 0.0102 - val_lenght_loss: 0.0080 - val_height_loss: 0.0022
# Epoch 19/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0098 - lenght_loss: 0.0074 - height_loss: 0.0024 - val_loss: 0.0100 - val_lenght_loss: 0.0078 - val_height_loss: 0.0022
# Epoch 20/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0097 - lenght_loss: 0.0073 - height_loss: 0.0024 - val_loss: 0.0099 - val_lenght_loss: 0.0077 - val_height_loss: 0.0021
# Epoch 21/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0096 - lenght_loss: 0.0072 - height_loss: 0.0024 - val_loss: 0.0098 - val_lenght_loss: 0.0076 - val_height_loss: 0.0021
# Epoch 22/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0094 - lenght_loss: 0.0071 - height_loss: 0.0023 - val_loss: 0.0096 - val_lenght_loss: 0.0075 - val_height_loss: 0.0021
# Epoch 23/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0094 - lenght_loss: 0.0070 - height_loss: 0.0023 - val_loss: 0.0095 - val_lenght_loss: 0.0075 - val_height_loss: 0.0021
# Epoch 24/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0092 - lenght_loss: 0.0069 - height_loss: 0.0023 - val_loss: 0.0094 - val_lenght_loss: 0.0074 - val_height_loss: 0.0021
# Epoch 25/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0091 - lenght_loss: 0.0069 - height_loss: 0.0023 - val_loss: 0.0093 - val_lenght_loss: 0.0073 - val_height_loss: 0.0020
# Epoch 26/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0090 - lenght_loss: 0.0068 - height_loss: 0.0023 - val_loss: 0.0093 - val_lenght_loss: 0.0072 - val_height_loss: 0.0020
# Epoch 27/40
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0089 - lenght_loss: 0.0067 - height_loss: 0.0022 - val_loss: 0.0091 - val_lenght_loss: 0.0071 - val_height_loss: 0.0020
# Epoch 28/40
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0088 - lenght_loss: 0.0066 - height_loss: 0.0022 - val_loss: 0.0090 - val_lenght_loss: 0.0070 - val_height_loss: 0.0020
# Epoch 29/40
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0087 - lenght_loss: 0.0065 - height_loss: 0.0022 - val_loss: 0.0089 - val_lenght_loss: 0.0070 - val_height_loss: 0.0020
# Epoch 30/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0086 - lenght_loss: 0.0065 - height_loss: 0.0022 - val_loss: 0.0089 - val_lenght_loss: 0.0069 - val_height_loss: 0.0019
# Epoch 31/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0086 - lenght_loss: 0.0064 - height_loss: 0.0021 - val_loss: 0.0087 - val_lenght_loss: 0.0068 - val_height_loss: 0.0019
# Epoch 32/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0084 - lenght_loss: 0.0063 - height_loss: 0.0021 - val_loss: 0.0086 - val_lenght_loss: 0.0067 - val_height_loss: 0.0019
# Epoch 33/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0084 - lenght_loss: 0.0063 - height_loss: 0.0021 - val_loss: 0.0085 - val_lenght_loss: 0.0066 - val_height_loss: 0.0019
# Epoch 34/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0082 - lenght_loss: 0.0062 - height_loss: 0.0021 - val_loss: 0.0084 - val_lenght_loss: 0.0066 - val_height_loss: 0.0019
# Epoch 35/40
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0082 - lenght_loss: 0.0061 - height_loss: 0.0021 - val_loss: 0.0084 - val_lenght_loss: 0.0065 - val_height_loss: 0.0019
# Epoch 36/40
# 96/96 [==============================] - 3s 30ms/step - loss: 0.0080 - lenght_loss: 0.0060 - height_loss: 0.0020 - val_loss: 0.0082 - val_lenght_loss: 0.0064 - val_height_loss: 0.0018
# Epoch 37/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0080 - lenght_loss: 0.0060 - height_loss: 0.0020 - val_loss: 0.0082 - val_lenght_loss: 0.0063 - val_height_loss: 0.0018
# Epoch 38/40
# 96/96 [==============================] - 3s 32ms/step - loss: 0.0079 - lenght_loss: 0.0059 - height_loss: 0.0020 - val_loss: 0.0081 - val_lenght_loss: 0.0063 - val_height_loss: 0.0018
# Epoch 39/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0078 - lenght_loss: 0.0058 - height_loss: 0.0020 - val_loss: 0.0079 - val_lenght_loss: 0.0061 - val_height_loss: 0.0018
# Epoch 40/40
# 96/96 [==============================] - 3s 31ms/step - loss: 0.0077 - lenght_loss: 0.0058 - height_loss: 0.0019 - val_loss: 0.0079 - val_lenght_loss: 0.0061 - val_height_loss: 0.0018

# %%
# plot loss and metrics: mse and mae
import matplotlib.pyplot as plt

# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training and validation loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
score = model_3.evaluate(test_manta, [test_feats[:, 0], test_feats[:, 1]], verbose=0)
print(score)
# Out:
# [0.00913948006927967, 0.006840184796601534, 0.002299293875694275]

# %%
# eval regression model
from sklearn.metrics import r2_score

y_pred_l, y_pred_h = model_3.predict(test_manta)#X_test)
#r2_l = r2_score(y_test[:,0], y_pred_l)
#r2_h = r2_score(y_test[:,1], y_pred_h)
r2_l = r2_score(test_feats[:,0], y_pred_l)
r2_h = r2_score(test_feats[:,1], y_pred_h)
print("r2 score: ", r2_l, r2_h)
# Out:
# 60/60 [==============================] - 1s 10ms/step
# r2 score:  0.8741791395786676 0.803294794373564

# %%
import matplotlib.pyplot as plt

# Increase overall text size
plt.rcParams.update({'font.size': 12})

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the first scatter plot (length prediction)
axs[0].scatter(test_feats[:, 0], y_pred_l, alpha=0.7, edgecolors='w', label='Manta Channel Test')
#axs[0].scatter(y_test_new[:, 0], y_pred_l_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[0].plot([min(test_feats[:, 0]), max(test_feats[:, 0])], [min(test_feats[:, 0]), max(test_feats[:, 0])], '--', color='red', linewidth=2)
axs[0].set_title("Length Prediction")
axs[0].set_xlabel("True Length")
axs[0].set_ylabel("Predicted Length")
axs[0].legend()
axs[0].grid(True)

# Plotting the second scatter plot (height prediction)
axs[1].scatter(test_feats[:, 1], y_pred_h, alpha=0.7, edgecolors='w', label='Manta Channel Test')
#axs[1].scatter(y_test_new[:, 1], y_pred_h_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[1].plot([min(test_feats[:, 1]), max(test_feats[:, 1])], [min(test_feats[:, 1]), max(test_feats[:, 1])], '--', color='red', linewidth=2)
axs[1].set_title("Height Prediction")
axs[1].set_xlabel("True Height")
axs[1].set_ylabel("Predicted Height")
axs[1].legend()
axs[1].grid(True)

# Adjust layout for better visualization
plt.tight_layout()

# Show the plot
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA


N_LAYER = -3

def eval_tsne_pca(model, n_layer, x_test, y_test, plot=True):
    
    # Get intermediate layer output and print the name
    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[n_layer].output)
    layer_name = model.layers[n_layer].name
    print("Layer name:", layer_name)
    
    intermediate_activations = intermediate_layer_model.predict(x_test)

    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(intermediate_activations)

    # Visualize t-SNE results
    if plot:
        plt.figure(figsize=(8, 6))
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 0], cmap='viridis', alpha=0.7)
        plt.title(f't-SNE Visualization - Layer: {layer_name}')
        plt.xlabel('t-SNE Dimension 1')
        plt.ylabel('t-SNE Dimension 2')
        plt.colorbar(label='Class')
        plt.grid(True)
        plt.show()

    # Apply PCA
    pca = PCA(n_components=2)
    pca_results = pca.fit_transform(intermediate_activations)

    # Visualize PCA results
    if plot:
        plt.figure(figsize=(8, 6))
        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 0], cmap='viridis', alpha=0.7)
        plt.title(f'PCA Visualization - Layer: {layer_name}')
        plt.xlabel('PCA Dimension 1')
        plt.ylabel('PCA Dimension 2')
        plt.colorbar(label='Class')
        plt.grid(True)
        plt.show()

    return tsne_results, pca_results

eval_tsne_pca(model_3, n_layer=N_LAYER, x_test=test_manta, y_test=test_feats, plot=True)


# eval for X_test_new
# Out:
# Layer name: dense_8
# 60/60 [==============================] - 1s 9ms/step
# (array([[ 50.72019   ,  -0.78149307],
#         [  3.3270693 ,  62.224953  ],
#         [ 39.81382   , -16.609789  ],
#         ...,
#         [  7.237503  , -41.893482  ],
#         [-43.30535   ,   4.531026  ],
#         [ 26.831758  , -22.580057  ]], dtype=float32),
#  array([[ 0.5397813 , -0.03828204],
#         [ 0.07223975,  0.4964733 ],
#         [ 0.3060126 , -0.36741984],
#         ...,
#         [-0.06965395, -0.25403056],
#         [-0.48846543, -0.13278173],
#         [ 0.36560163, -0.36308587]], dtype=float32))
