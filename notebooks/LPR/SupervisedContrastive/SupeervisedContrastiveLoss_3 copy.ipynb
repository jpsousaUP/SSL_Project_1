# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation
import tensorflow_addons as tfa
import numpy as np

import matplotlib.pyplot as plt

# verify if GPU is available
print(tf.test.is_gpu_available())

# set memory growth to true
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Setting memory growth to True for GPU: ", physical_devices[0])
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# dont display much info of tensorflow
tf.get_logger().setLevel('ERROR')
# Out:
# 2024-01-26 15:10:35.870103: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-26 15:10:36.004851: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 15:10:36.004902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 15:10:36.012578: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 15:10:36.034379: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-26 15:10:36.943432: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/vm/laser/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# WARNING:tensorflow:From /tmp/ipykernel_142453/306569446.py:10: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# Setting memory growth to True for GPU:  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# 2024-01-26 15:10:38.082629: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.177895: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.178107: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.286207: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.286372: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.286483: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.286570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /device:GPU:0 with 46874 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:07:00.0, compute capability: 8.6
# 2024-01-26 15:10:38.288300: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.288461: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-26 15:10:38.288551: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Load data
manta_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_manta.npy"
xiris_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_xiris.npy"
y_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_y.npy"
feats_path = "/home/vm/SSL_Project_1/data/processed/bag_2023-07-04_15-23-48/_feats.npy"

# load numpy arrays and display shapes
manta = np.load(manta_path)
xiris = np.load(xiris_path)
params = np.load(y_path)
print("manta shape: ", manta.shape)
print("xiris shape: ", xiris.shape)
feats = np.load(feats_path)
print("feats shape: ", feats.shape)

# use laser power and velocity as labels
params = params[:, :2]
print("y shape: ", params.shape)

y = np.concatenate((params, feats[:, 1:3]), axis=1) # L, H
print("y shape: ", y.shape)

y_max = np.max(y, axis=0)
y = y / y_max

# print max of each column
print("max of each column: ", y_max)
# Out:
# manta shape:  (9587, 320, 320)
# xiris shape:  (9587, 320, 320)
# feats shape:  (9587, 8)
# y shape:  (9587, 2)
# y shape:  (9587, 4)
# max of each column:  [2750.   15.  232.  159.]

# %%
# shuffle manta and xiris without lossign correspondence y values
indices = np.arange(manta.shape[0])
# seed
np.random.seed(42)
np.random.shuffle(indices)

manta = manta[indices]
xiris = xiris[indices]
y = y[indices]

# split data into train, validation and test
train_split = 0.8
test_split = 0.2

train_split_idx = int(manta.shape[0] * train_split)
test_split_idx = int(manta.shape[0] * test_split)

x_train_manta = manta[:train_split_idx]
x_train_xiris = xiris[:train_split_idx]
y_train = y[:train_split_idx]

x_test_manta = manta[train_split_idx:]
x_test_xiris = xiris[train_split_idx:]
y_test = y[train_split_idx:]

X_train = np.concatenate((x_train_manta, x_train_xiris), axis=0)
y_train = np.concatenate((y_train, y_train), axis=0)

# shapes
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)

y_test_all = np.concatenate((y_test, y_test), axis=0)
# Out:
# X_train shape:  (15338, 320, 320)
# y_train shape:  (15338, 4)

# %%
def create_encoder(input_shape=(320, 320, 1)):
    inputs = Input(shape=input_shape)
    x = Conv2D(16, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    
    model = Model(inputs=inputs, outputs=x)
    return model

def add_projection_head(input_shape, encoder, embedding_dim, regression_dim=1):
    inputs = Input(shape=input_shape)
    features = encoder(inputs)
    
    contrastive_outputs = [Dense(embedding_dim, activation='sigmoid', name=f"contrastive_output_{i}", use_bias=False)(features) for i in range(num_tasks)]

    # merge contrastive outputs
    merged_contrastive_outputs = tf.keras.layers.concatenate(contrastive_outputs, axis=1)
    
  
    model = Model(inputs=inputs, outputs=contrastive_outputs)
    return model

class SupConModel(Model):
    def __init__(self, sup_model, temperature=0.05):
        super().__init__()
        self.sup_model = sup_model
        self.temperature = 0.05
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")

    def call(self, inputs):
        return self.sup_model(inputs)

    def train_step(self, data):
        X, y = data

        with tf.GradientTape() as tape_contrastive:
            y_pred = self.sup_model(X)
            loss_p = self.supervised_contrastive_loss(y[:, 0], y_pred[0])
            loss_v = self.supervised_contrastive_loss(y[:, 1], y_pred[1])
            loss = loss_p + loss_v

        gradients_contrastive = tape_contrastive.gradient(loss, self.sup_model.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients_contrastive, self.sup_model.trainable_weights))

        self.loss_tracker.update_state(loss)
        
        return {"loss": self.loss_tracker.result()}
    
    def test_step(self, data):
        X, y = data

        y_pred = self.sup_model(X)
        loss_p = self.supervised_contrastive_loss(y[:, 0], y_pred[0])
        loss_v = self.supervised_contrastive_loss(y[:, 1], y_pred[1])

        loss = loss_p + loss_v
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}

    def supervised_contrastive_loss(self, labels, feature_vectors):
        # Normalize feature vectors
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        # Compute logits
        logits = tf.divide(
            tf.matmul(
                feature_vectors_normalized, tf.transpose(feature_vectors_normalized)
            ),
            self.temperature,
        )
        return tfa.losses.npairs_loss(tf.squeeze(labels), logits)

    @property
    def metrics(self):
        return [self.loss_tracker]

input_shape = (320, 320, 1)
embedding_dim = 128
regression_dim = 1
num_tasks = 2  # Number of contrastive tasks

encoder = create_encoder(input_shape)
encoder_with_projection_head = add_projection_head(input_shape, encoder, embedding_dim, regression_dim)
encoder_with_projection_head.summary()
    
model = SupConModel(encoder_with_projection_head, temperature=0.05)
for i, layer in enumerate(model.sup_model.layers):
    print(i, layer.name)
    
learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate))

batch_size = 64
epochs = 50

history = model.fit(x=X_train, y=y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_2 (Functional)        (None, 128)                  1185267   ['input_4[0][0]']
#                                                           2
#
#  contrastive_output_0 (Dens  (None, 128)                  16384     ['model_2[0][0]']
#  e)
#
#  contrastive_output_1 (Dens  (None, 128)                  16384     ['model_2[0][0]']
#  e)
#
# ==================================================================================================
# Total params: 11885440 (45.34 MB)
# Trainable params: 11885440 (45.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 0 input_4
# 1 model_2
# 2 contrastive_output_0
# 3 contrastive_output_1
# [<keras.src.engine.input_layer.InputLayer object at 0x7f14355f6590>, <keras.src.engine.functional.Functional object at 0x7f14355f6c20>, <keras.src.layers.core.dense.Dense object at 0x7f14355f41f0>, <keras.src.layers.core.dense.Dense object at 0x7f14355f7d00>]
# []
# Epoch 1/50
# 192/192 [==============================] - 14s 69ms/step - loss: 7.4621 - val_loss: 7.2947
# Epoch 2/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.7082 - val_loss: 6.7348
# Epoch 3/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.4907 - val_loss: 6.6377
# Epoch 4/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.3996 - val_loss: 6.4876
# Epoch 5/50
# 192/192 [==============================] - 9s 45ms/step - loss: 6.3445 - val_loss: 6.4221
# Epoch 6/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.3080 - val_loss: 6.4128
# Epoch 7/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.2819 - val_loss: 6.3245
# Epoch 8/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.2593 - val_loss: 6.3434
# Epoch 9/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.2349 - val_loss: 6.2780
# Epoch 10/50
# 192/192 [==============================] - 9s 45ms/step - loss: 6.2068 - val_loss: 6.2389
# Epoch 11/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.1954 - val_loss: 6.2362
# Epoch 12/50
# 192/192 [==============================] - 9s 44ms/step - loss: 6.1889 - val_loss: 6.2129
# Epoch 13/50
# 192/192 [==============================] - 9s 46ms/step - loss: 6.1783 - val_loss: 6.1720
# Epoch 14/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.1809 - val_loss: 6.1623
# Epoch 15/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.1652 - val_loss: 6.1708
# Epoch 16/50
# 192/192 [==============================] - 9s 46ms/step - loss: 6.1536 - val_loss: 6.1807
# Epoch 17/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.1518 - val_loss: 6.1750
# Epoch 18/50
# 192/192 [==============================] - 7s 38ms/step - loss: 6.1363 - val_loss: 6.1471
# Epoch 19/50
# 192/192 [==============================] - 7s 35ms/step - loss: 6.1413 - val_loss: 6.1294
# Epoch 20/50
# 192/192 [==============================] - 7s 35ms/step - loss: 6.1323 - val_loss: 6.1455
# Epoch 21/50
# 192/192 [==============================] - 7s 38ms/step - loss: 6.1326 - val_loss: 6.1263
# Epoch 22/50
# 192/192 [==============================] - 7s 34ms/step - loss: 6.1272 - val_loss: 6.1108
# Epoch 23/50
# 192/192 [==============================] - 7s 38ms/step - loss: 6.1331 - val_loss: 6.0927
# Epoch 24/50
# 192/192 [==============================] - 6s 33ms/step - loss: 6.1110 - val_loss: 6.1083
# Epoch 25/50
# 192/192 [==============================] - 6s 34ms/step - loss: 6.1025 - val_loss: 6.0949
# Epoch 26/50
# 192/192 [==============================] - 7s 37ms/step - loss: 6.1083 - val_loss: 6.0880
# Epoch 27/50
# 192/192 [==============================] - 7s 35ms/step - loss: 6.1104 - val_loss: 6.1225
# Epoch 28/50
# 192/192 [==============================] - 7s 36ms/step - loss: 6.1057 - val_loss: 6.1131
# Epoch 29/50
# 192/192 [==============================] - 7s 37ms/step - loss: 6.0993 - val_loss: 6.1016
# Epoch 30/50
# 192/192 [==============================] - 7s 34ms/step - loss: 6.1009 - val_loss: 6.1011
# Epoch 31/50
# 192/192 [==============================] - 7s 37ms/step - loss: 6.0903 - val_loss: 6.0792
# Epoch 32/50
# 192/192 [==============================] - 6s 34ms/step - loss: 6.1049 - val_loss: 6.0914
# Epoch 33/50
# 192/192 [==============================] - 6s 33ms/step - loss: 6.0839 - val_loss: 6.0562
# Epoch 34/50
# 192/192 [==============================] - 6s 34ms/step - loss: 6.1017 - val_loss: 6.0884
# Epoch 35/50
# 192/192 [==============================] - 7s 37ms/step - loss: 6.0866 - val_loss: 6.0782
# Epoch 36/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.0826 - val_loss: 6.0754
# Epoch 37/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.0762 - val_loss: 6.1021
# Epoch 38/50
# 192/192 [==============================] - 9s 45ms/step - loss: 6.0754 - val_loss: 6.0804
# Epoch 39/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.0821 - val_loss: 6.0750
# Epoch 40/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.0677 - val_loss: 6.0647
# Epoch 41/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.0723 - val_loss: 6.0560
# Epoch 42/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.0683 - val_loss: 6.0697
# Epoch 43/50
# 192/192 [==============================] - 8s 43ms/step - loss: 6.0658 - val_loss: 6.0979
# Epoch 44/50
# 192/192 [==============================] - 9s 44ms/step - loss: 6.0757 - val_loss: 6.0579
# Epoch 45/50
# 192/192 [==============================] - 9s 47ms/step - loss: 6.0675 - val_loss: 6.0671
# Epoch 46/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.0644 - val_loss: 6.0635
# Epoch 47/50
# 192/192 [==============================] - 9s 45ms/step - loss: 6.0636 - val_loss: 6.0522
# Epoch 48/50
# 192/192 [==============================] - 9s 45ms/step - loss: 6.0632 - val_loss: 6.0647
# Epoch 49/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.0623 - val_loss: 6.0933
# Epoch 50/50
# 192/192 [==============================] - 8s 44ms/step - loss: 6.0629 - val_loss: 6.0587

# %%
# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training and validation loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
for i, layer in enumerate(model.sup_model.layers):
    print(i, layer.name)
# Out:
# 0 input_4
# 1 model_2
# 2 contrastive_output_0
# 3 contrastive_output_1

# %%
# Create a new model by copying the architecture
new_model = Model(inputs=model.sup_model.input, outputs=[model.sup_model.layers[2].output, model.sup_model.layers[3].output])
# remove layer 4 and 5
new_model.summary()

# set weights of new model to weights of trained model for each layer except the last 2 layers
for layer in new_model.layers:
    layer.set_weights(model.sup_model.get_layer(layer.name).get_weights())
    print(layer.name, "weights set")
    layer.trainable = False
    

inputs = Input(shape=(320, 320, 1))
x = new_model(inputs)
# merge the last 2 layers in a single layer
x = layers.concatenate(x)
# add a two regression heads
#x = Dense(128, activation='relu')(x)
output_l = Dense(1, activation="linear", name="lenght")(x)
output_h = Dense(1, activation="linear", name="height")(x)

model_3 = Model(inputs=inputs, outputs=[output_l, output_h])
model_3.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_2 (Functional)        (None, 128)                  1185267   ['input_4[0][0]']
#                                                           2
#
#  contrastive_output_0 (Dens  (None, 128)                  16384     ['model_2[0][0]']
#  e)
#
#  contrastive_output_1 (Dens  (None, 128)                  16384     ['model_2[0][0]']
#  e)
#
# ==================================================================================================
# Total params: 11885440 (45.34 MB)
# Trainable params: 11885440 (45.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# input_4 weights set
# model_2 weights set
# contrastive_output_0 weights set
# contrastive_output_1 weights set
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 320, 320, 1)]        0         []
#
#  model_4 (Functional)        [(None, 128),                1188544   ['input_5[0][0]']
#                               (None, 128)]                0
#
#  concatenate_2 (Concatenate  (None, 256)                  0         ['model_4[0][0]',
#  )                                                                   'model_4[0][1]']
#
#  lenght (Dense)              (None, 1)                    257       ['concatenate_2[0][0]']
#
#  height (Dense)              (None, 1)                    257       ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 11885954 (45.34 MB)
# Trainable params: 514 (2.01 KB)
# Non-trainable params: 11885440 (45.34 MB)
# __________________________________________________________________________________________________

# %%
# fit model
learning_rate = 0.0001
model_3.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='mse')

batch_size = 64
epochs = 25

history = model_3.fit(x=X_train, 
            y=[y_train[:, 2], y_train[:, 3]],
            #y=y_train[:, 2:], # L, H
            batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/25
# 192/192 [==============================] - 12s 53ms/step - loss: 0.1929 - lenght_loss: 0.0903 - height_loss: 0.1026 - val_loss: 0.0624 - val_lenght_loss: 0.0360 - val_height_loss: 0.0265
# Epoch 2/25
# 192/192 [==============================] - 6s 29ms/step - loss: 0.0424 - lenght_loss: 0.0263 - height_loss: 0.0161 - val_loss: 0.0312 - val_lenght_loss: 0.0199 - val_height_loss: 0.0113
# Epoch 3/25
# 192/192 [==============================] - 6s 29ms/step - loss: 0.0248 - lenght_loss: 0.0167 - height_loss: 0.0081 - val_loss: 0.0226 - val_lenght_loss: 0.0142 - val_height_loss: 0.0085
# Epoch 4/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0191 - lenght_loss: 0.0131 - height_loss: 0.0060 - val_loss: 0.0199 - val_lenght_loss: 0.0123 - val_height_loss: 0.0076
# Epoch 5/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0174 - lenght_loss: 0.0119 - height_loss: 0.0054 - val_loss: 0.0191 - val_lenght_loss: 0.0117 - val_height_loss: 0.0074
# Epoch 6/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0169 - lenght_loss: 0.0116 - height_loss: 0.0053 - val_loss: 0.0189 - val_lenght_loss: 0.0115 - val_height_loss: 0.0074
# Epoch 7/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0167 - lenght_loss: 0.0114 - height_loss: 0.0053 - val_loss: 0.0187 - val_lenght_loss: 0.0114 - val_height_loss: 0.0073
# Epoch 8/25
# 192/192 [==============================] - 6s 31ms/step - loss: 0.0165 - lenght_loss: 0.0113 - height_loss: 0.0052 - val_loss: 0.0185 - val_lenght_loss: 0.0112 - val_height_loss: 0.0072
# Epoch 9/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0164 - lenght_loss: 0.0112 - height_loss: 0.0052 - val_loss: 0.0184 - val_lenght_loss: 0.0111 - val_height_loss: 0.0072
# Epoch 10/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0163 - lenght_loss: 0.0111 - height_loss: 0.0051 - val_loss: 0.0181 - val_lenght_loss: 0.0110 - val_height_loss: 0.0071
# Epoch 11/25
# 192/192 [==============================] - 6s 31ms/step - loss: 0.0161 - lenght_loss: 0.0110 - height_loss: 0.0051 - val_loss: 0.0178 - val_lenght_loss: 0.0108 - val_height_loss: 0.0070
# Epoch 12/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0160 - lenght_loss: 0.0109 - height_loss: 0.0050 - val_loss: 0.0178 - val_lenght_loss: 0.0108 - val_height_loss: 0.0070
# Epoch 13/25
# 192/192 [==============================] - 5s 29ms/step - loss: 0.0158 - lenght_loss: 0.0108 - height_loss: 0.0050 - val_loss: 0.0174 - val_lenght_loss: 0.0105 - val_height_loss: 0.0069
# Epoch 14/25
# 192/192 [==============================] - 6s 29ms/step - loss: 0.0156 - lenght_loss: 0.0107 - height_loss: 0.0049 - val_loss: 0.0171 - val_lenght_loss: 0.0103 - val_height_loss: 0.0068
# Epoch 15/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0154 - lenght_loss: 0.0106 - height_loss: 0.0048 - val_loss: 0.0168 - val_lenght_loss: 0.0102 - val_height_loss: 0.0067
# Epoch 16/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0153 - lenght_loss: 0.0105 - height_loss: 0.0048 - val_loss: 0.0165 - val_lenght_loss: 0.0100 - val_height_loss: 0.0065
# Epoch 17/25
# 192/192 [==============================] - 6s 29ms/step - loss: 0.0151 - lenght_loss: 0.0104 - height_loss: 0.0047 - val_loss: 0.0162 - val_lenght_loss: 0.0098 - val_height_loss: 0.0064
# Epoch 18/25
# 192/192 [==============================] - 6s 31ms/step - loss: 0.0149 - lenght_loss: 0.0103 - height_loss: 0.0046 - val_loss: 0.0159 - val_lenght_loss: 0.0097 - val_height_loss: 0.0063
# Epoch 19/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0147 - lenght_loss: 0.0102 - height_loss: 0.0046 - val_loss: 0.0157 - val_lenght_loss: 0.0095 - val_height_loss: 0.0062
# Epoch 20/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0146 - lenght_loss: 0.0101 - height_loss: 0.0045 - val_loss: 0.0154 - val_lenght_loss: 0.0094 - val_height_loss: 0.0060
# Epoch 21/25
# 192/192 [==============================] - 5s 29ms/step - loss: 0.0144 - lenght_loss: 0.0100 - height_loss: 0.0044 - val_loss: 0.0152 - val_lenght_loss: 0.0093 - val_height_loss: 0.0059
# Epoch 22/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0142 - lenght_loss: 0.0098 - height_loss: 0.0043 - val_loss: 0.0148 - val_lenght_loss: 0.0091 - val_height_loss: 0.0058
# Epoch 23/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0140 - lenght_loss: 0.0097 - height_loss: 0.0043 - val_loss: 0.0147 - val_lenght_loss: 0.0090 - val_height_loss: 0.0056
# Epoch 24/25
# 192/192 [==============================] - 6s 30ms/step - loss: 0.0138 - lenght_loss: 0.0097 - height_loss: 0.0042 - val_loss: 0.0143 - val_lenght_loss: 0.0088 - val_height_loss: 0.0055
# Epoch 25/25
# 192/192 [==============================] - 6s 31ms/step - loss: 0.0137 - lenght_loss: 0.0096 - height_loss: 0.0041 - val_loss: 0.0140 - val_lenght_loss: 0.0087 - val_height_loss: 0.0054

# %%
# Get test datasets
X_test = np.concatenate((x_test_manta, x_test_xiris), axis=0)
#x_test_manta
y_test_manta = y_test
y_test = np.concatenate((y_test, y_test), axis=0)

# %%
score = model_3.evaluate(X_test, [y_test[:, 2], y_test[:, 3]], verbose=0)
print(score)
# Out:
# [0.017267780378460884, 0.011491237208247185, 0.005776538513600826]

# %%
# eval regression model
from sklearn.metrics import r2_score

y_pred_l, y_pred_h = model_3.predict(X_test)
r2_l = r2_score(y_test[:,2], y_pred_l)
r2_h = r2_score(y_test[:,3], y_pred_h)
print("r2 score: ", r2_l, r2_h)
# Out:
# 120/120 [==============================] - 1s 11ms/step
# r2 score:  0.7886259833723004 0.5058156260930211

# %%
y_pred_l_new, y_pred_h_new = model_3.predict(x_test_manta)
r2_l_new = r2_score(y_test_manta[:,2], y_pred_l_new)
r2_h_new = r2_score(y_test_manta[:,3], y_pred_h_new)

print("r2 score: ", r2_l_new, r2_h_new)
# Out:
# 60/60 [==============================] - 1s 9ms/step
# r2 score:  0.7736812987374041 0.6604879083597825

# %%
y_test_new = y_test_manta

# %%
import matplotlib.pyplot as plt

# Increase overall text size
plt.rcParams.update({'font.size': 12})

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the first scatter plot (length prediction)
axs[0].scatter(y_test[:, 2], y_pred_l, alpha=0.7, edgecolors='w', label='Both Channels')
axs[0].scatter(y_test_new[:, 2], y_pred_l_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[0].plot([min(y_test[:, 2]), max(y_test[:, 2])], [min(y_test[:, 2]), max(y_test[:, 2])], '--', color='red', linewidth=2)
axs[0].set_title("Length Prediction")
axs[0].set_xlabel("True Length")
axs[0].set_ylabel("Predicted Length")
axs[0].legend()
axs[0].grid(True)

# Plotting the second scatter plot (height prediction)
axs[1].scatter(y_test[:, 3], y_pred_h, alpha=0.7, edgecolors='w', label='Both Channels')
axs[1].scatter(y_test_new[:, 3], y_pred_h_new, alpha=0.7, edgecolors='w', label='Only Channel 1')
axs[1].plot([min(y_test[:, 3]), max(y_test[:, 3])], [min(y_test[:, 3]), max(y_test[:, 3])], '--', color='red', linewidth=2)
axs[1].set_title("Height Prediction")
axs[1].set_xlabel("True Height")
axs[1].set_ylabel("Predicted Height")
axs[1].legend()
axs[1].grid(True)

# Adjust layout for better visualization
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

N_LAYER = -3

def eval_tsne_pca(model, n_layer, x_test, y_test, plot=True):
    
    # Get intermediate layer output and print the name
    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[n_layer].output)
    layer_name = model.layers[n_layer].name
    print("Layer name:", layer_name)
    
    intermediate_activations = intermediate_layer_model.predict(x_test)

    # Apply t-SNE
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(intermediate_activations)

    # Visualize t-SNE results
    if plot:
        plt.figure(figsize=(8, 6))
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 2], cmap='viridis', alpha=0.7)
        plt.title(f't-SNE Visualization - Layer: {layer_name}')
        plt.xlabel('t-SNE Dimension 1')
        plt.ylabel('t-SNE Dimension 2')
        plt.colorbar(label='Class')
        plt.grid(True)
        plt.show()

    # Apply PCA
    pca = PCA(n_components=2)
    pca_results = pca.fit_transform(intermediate_activations)

    # Visualize PCA results
    if plot:
        plt.figure(figsize=(8, 6))
        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 2], cmap='viridis', alpha=0.7)
        plt.title(f'PCA Visualization - Layer: {layer_name}')
        plt.xlabel('PCA Dimension 1')
        plt.ylabel('PCA Dimension 2')
        plt.colorbar(label='Class')
        plt.grid(True)
        plt.show()

    return tsne_results, pca_results

eval_tsne_pca(model.sup_model, n_layer=N_LAYER, x_test=X_test, y_test=y_test, plot=True)

eval_tsne_pca(model.sup_model, n_layer=N_LAYER, x_test=x_test_manta, y_test=y_test_manta, plot=True)
# Out:
# Layer name: dense
# 120/120 [==============================] - 1s 9ms/step
# Layer name: dense
# 60/60 [==============================] - 1s 9ms/step
# (array([[ 20.171215 ,  34.23694  ],
#         [ -5.0706706, -10.401028 ],
#         [ 33.999054 ,   3.3397427],
#         ...,
#         [ 16.758091 , -37.067707 ],
#         [-13.094209 ,  29.601698 ],
#         [ 36.809795 ,   2.0386386]], dtype=float32),
#  array([[ 0.9425021 ,  0.46666306],
#         [-0.41339815, -0.12734671],
#         [ 1.188874  ,  0.3321193 ],
#         ...,
#         [ 0.27154526, -0.63086635],
#         [-0.87287945,  0.5072191 ],
#         [ 1.1888437 ,  0.33201048]], dtype=float32))

# %%
""" from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

N_LAYER = -3

def eval_tsne_pca(model, n_layer, x_test, y_test, plot=True):
    
    # Get intermediate layer output and print the name
    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[n_layer].output)
    layer_name = model.layers[n_layer].name
    print("Layer name:", layer_name)
    
    intermediate_activations = intermediate_layer_model.predict(x_test)

    # Apply t-SNE or PCA
    tsne = TSNE(n_components=2, random_state=42)
    tsne_results = tsne.fit_transform(intermediate_activations)

    # Visualize t-SNE results
    if plot:
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    # apply PCA
    pca = PCA(n_components=2)
    pca_results = pca.fit_transform(intermediate_activations)

    # Visualize PCA results
    if plot:
        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 0], cmap='jet')
        plt.colorbar()
        plt.show()

    return tsne_results, pca_results

eval_tsne_pca(model_3, n_layer=N_LAYER, x_test=X_test, y_test=y_test, plot=True)

eval_tsne_pca(model_3, n_layer=N_LAYER, x_test=X_test_new, y_test=y_test_new, plot=True)

# eval for X_test_new
 """
# Out:
# ' from sklearn.manifold import TSNE\nfrom sklearn.decomposition import PCA\n\nN_LAYER = -3\n\ndef eval_tsne_pca(model, n_layer, x_test, y_test, plot=True):\n    \n    # Get intermediate layer output and print the name\n    intermediate_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[n_layer].output)\n    layer_name = model.layers[n_layer].name\n    print("Layer name:", layer_name)\n    \n    intermediate_activations = intermediate_layer_model.predict(x_test)\n\n    # Apply t-SNE or PCA\n    tsne = TSNE(n_components=2, random_state=42)\n    tsne_results = tsne.fit_transform(intermediate_activations)\n\n    # Visualize t-SNE results\n    if plot:\n        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test[:, 0], cmap=\'jet\')\n        plt.colorbar()\n        plt.show()\n\n    # apply PCA\n    pca = PCA(n_components=2)\n    pca_results = pca.fit_transform(intermediate_activations)\n\n    # Visualize PCA results\n    if plot:\n        plt.scatter(pca_results[:, 0], pca_results[:, 1], c=y_test[:, 0], cmap=\'jet\')\n        plt.colorbar()\n        plt.show()\n\n    return tsne_results, pca_results\n\neval_tsne_pca(model_3, n_layer=N_LAYER, x_test=X_test, y_test=y_test, plot=True)\n\neval_tsne_pca(model_3, n_layer=N_LAYER, x_test=X_test_new, y_test=y_test_new, plot=True)\n\n# eval for X_test_new\n '
